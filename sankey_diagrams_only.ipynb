# %% [markdown]
# <div style="border: 2px solid #575757; padding: 10px; border-radius: 5px; background-color: #e1e1e1; color: black; text-align: center;">
#   <h1 style="margin: 0;">Sankey Diagrams Only: Balance of Electricity / H<sub>2</sub> / Heat flow</h1>
# </div>

# %% [markdown]
# <div style="border: 2px solid #FFA500; padding: 10px; border-radius: 5px; background-color: #FFFACD; color: black; text-align: center;">
#   <h2 style="margin: 0;">Libraries importation</h2>
# </div>

# %% [markdown]
# **Import required libraries:**

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import dash
from dash import dcc, html, Input, Output, State
import joblib
import plotly.io as pio

# %% [markdown]
# <div style="border: 2px solid #FFA500; padding: 10px; border-radius: 5px; background-color: #FFFACD; color: black; text-align: center;">
#   <h2 style="margin: 0;">Combining all Electricity / H<sub>2</sub> / Heat flows in Sankey diagrams</h2>
# </div>

# %% [markdown]
# **Display interactive Sankey diagrams :**
# - Vizualisation of all Electricity, Heat, and H<sub>2</sub>
# - Several display modes:
#   - Original: the flows are displayed as calculated
#   - Log: conversion of the values on a logarithmic scale
#   - Threshold: suppress flows and nodes under a certain value.
#   - Threshold and scaled: apply the threshold transformation and scales flows per type (electricity, heat, H<sub>2</sub>)
#
# **Help for interpretation:**
# - The "Threshold" display mode is needed as some variables of the OpenModelica model are sometimes set to 1 instead of 0 for mathematical reasons. For example, WT always appears in the "Original" Sankey diagram despite WT supposed to be absent in Scenarios 15-28. Same goes for BAT in Scenarios 22-28.
# - The "Threshold and scaled" display mode is needed to highlight the relative size of flows inside a given flow category (electricity, heat, H<sub>2</sub>)

# %%
########## LOAD RESULTS DATA AND DEFINE MAPPINGS ##########

# Load the necessary results data
all_elec_results = joblib.load("pickles/all_elec_results.pkl")
all_h2_results = joblib.load("pickles/all_h2_results.pkl")
all_heat_results = joblib.load("pickles/all_heat_results.pkl")

# Node Name Mapping
elec_mapping = {
    "Pchp": "ICE-CHP", "Pwind": "WT", "Ppv": "PV", "Pload": "LOAD", "Php": "HP",
    "Ppump": "P", "Pbat": "BAT", "Pgrid": "GRID", "Ppemel": "PEMEL", "Pcom": "H2C/S"
}

heat_mapping = {
    "Qchp": "ICE-CHP", "Qload": "LOAD", "Qhp": "HP", "Qtes": "TES"
}

h2_mapping = {
    "H2load": "ICE-CHP", "H2cs": "H2C/S", "H2pemel": "PEMEL"
}

# Colorblind-Friendly Node Color Mapping
node_color_map = {
    "PV": "#009E73", "WT": "#009E73", "GRID": "#009E73", "BAT": "#009E73",
    "ICE-CHP": "#4D4D4D", "PEMEL": "#005F99", "H2C/S": "#005F99",
    "LOAD": "#E69F00", "HP": "#882255", "TES": "#882255"
}

# Helper function to convert HEX to RGBA
def convert_to_rgba(hex_color, opacity):
    hex_color = hex_color.lstrip("#")
    r, g, b = tuple(int(hex_color[i:i+2], 16) for i in (0, 2, 4))
    return f"rgba({r},{g},{b},{opacity})"

# Load Data with mapping
def process_data(df, mapping, flow_type):
    flows = [col for col in df.columns if "->" in col]
    structured_data = []
    for _, row in df.iterrows():
        scenario = row["Scenario"]
        for flow in flows:
            source, target = [s.strip() for s in flow.split("->")]
            source = mapping.get(source, source)
            target = mapping.get(target, target)
            value = row[flow]
            structured_data.append({
                "Scenario": scenario, "Source": source, "Target": target,
                "Value": value, "FlowType": flow_type
            })
    return pd.DataFrame(structured_data)

elec_df = process_data(all_elec_results, elec_mapping, "elec")
h2_df = process_data(all_h2_results, h2_mapping, "h2")
heat_df = process_data(all_heat_results, heat_mapping, "heat")
df = pd.concat([elec_df, h2_df, heat_df])
if df.empty:
    raise ValueError("The combined DataFrame is empty. Check if the input data is loaded correctly.")

########## DEFINE NODES AND DATA TRANSFORMATIONS ##########

# Get Node List
all_nodes = sorted(list(set(df["Source"].tolist() + df["Target"].tolist())))
node_indices = {node: i for i, node in enumerate(all_nodes)}

# Define Transformation Functions
transformation_types = ['original', 'log', 'threshold', 'threshold & scaled']

def get_transformed_data(scenario, transformation, threshold_value=5):
    df_scenario = df[df["Scenario"] == scenario].copy()
    # Always store original values for hover display
    df_scenario["OriginalValue"] = df_scenario["Value"]

    # Apply the selected transformation
    if transformation == 'threshold':
        # Filter flows using the original values only, but do NOT change the node set.
        df_filtered = df_scenario[df_scenario["Value"] >= threshold_value].copy()
        return {
            "nodes": all_nodes,
            "source": [node_indices[src] for src in df_filtered["Source"]],
            "target": [node_indices[tgt] for tgt in df_filtered["Target"]],
            "value": df_filtered["Value"].tolist(),
            "flow_types": df_filtered["FlowType"].tolist(),
            "original_value": df_filtered["OriginalValue"].tolist()
        }

    elif transformation == 'threshold & scaled':
        max_elec = df_scenario[df_scenario["FlowType"] == "elec"]["Value"].max()
        max_heat = df_scenario[df_scenario["FlowType"] == "heat"]["Value"].max()
        max_h2 = df_scenario[df_scenario["FlowType"] == "h2"]["Value"].max()

        heat_scale_factor = (2 / 3) * max_elec / max_heat if max_heat > 0 else 1
        h2_scale_factor = (1 / 3) * max_elec / max_h2 if max_h2 > 0 else 1

        df_scenario["TransformedValue"] = df_scenario.apply(
            lambda row: row["Value"] * heat_scale_factor if row["FlowType"] == "heat" else
                        row["Value"] * h2_scale_factor if row["FlowType"] == "h2" else
                        row["Value"],
            axis=1
        )

        # Apply threshold after scaling
        df_filtered = df_scenario[df_scenario["TransformedValue"] >= threshold_value].copy()
        nodes_filtered = sorted(set(df_filtered["Source"].tolist() + df_filtered["Target"].tolist()))
        node_indices_filtered = {node: i for i, node in enumerate(nodes_filtered)}
        return {
            "nodes": nodes_filtered,
            "source": [node_indices_filtered[src] for src in df_filtered["Source"]],
            "target": [node_indices_filtered[tgt] for tgt in df_filtered["Target"]],
            "value": df_filtered["TransformedValue"].tolist(),
            "original_value": df_filtered["OriginalValue"].tolist(),
            "flow_types": df_filtered["FlowType"].tolist()
        }

    elif transformation == 'log':
        df_scenario["TransformedValue"] = np.log1p(df_scenario["Value"])

    elif transformation == 'original':
        df_scenario["TransformedValue"] = df_scenario["Value"]

    else:
        # Normalize if other future transformations are added
        max_val = df_scenario["Value"].max()
        df_scenario["TransformedValue"] = df_scenario["Value"] / max_val

    # For 'threshold only' and other default transformations, return all nodes
    return {
        "nodes": all_nodes,
        "source": [node_indices[src] for src in df_scenario["Source"]],
        "target": [node_indices[tgt] for tgt in df_scenario["Target"]],
        "value": df_scenario["TransformedValue"].tolist(),
        "original_value": df_scenario["OriginalValue"].tolist(),
        "flow_types": df_scenario["FlowType"].tolist()
    }

########## GENERATE SANKEY DIAGRAM ##########

def create_sankey_figure(scenario, transformation, threshold_value=5, opacity=0.5, label_size=30):
    data_trans = get_transformed_data(scenario, transformation, threshold_value)
    # For transformed cases, use filtered nodes; otherwise, all nodes.
    nodes_used = data_trans["nodes"] if transformation == 'threshold & scaled' else all_nodes
    current_node_indices = {node: i for i, node in enumerate(nodes_used)}

    # Colors for nodes and links
    node_colors = [convert_to_rgba(node_color_map.get(node, "#BBBBBB"), opacity) for node in nodes_used]
    link_colors = [
        convert_to_rgba("#009E73", opacity) if flow_type == "elec" else
        convert_to_rgba("#882255", opacity) if flow_type == "heat" else
        convert_to_rgba("#005F99", opacity)
        for flow_type in data_trans["flow_types"]
    ]

    # Build hover text using the original values.
    # Note: The source and target indices in data_trans refer to positions in the nodes list.
    hover_text = []
    # Use the node names from nodes_used if filtered, else from all_nodes.
    for src_idx, tgt_idx, orig in zip(data_trans["source"], data_trans["target"], data_trans["original_value"]):
        # When using full nodes, src_idx and tgt_idx are valid indices into all_nodes.
        # When using filtered nodes, they are valid into nodes_used.
        src_name = nodes_used[src_idx]
        tgt_name = nodes_used[tgt_idx]
        hover_text.append(f"{src_name} → {tgt_name}: {orig:.2f}")

    sankey = go.Sankey(
        node=dict(pad=15, thickness=20, line=dict(color="black", width=0.5),
                  label=nodes_used, color=node_colors),
        link=dict(source=data_trans["source"], target=data_trans["target"],
                  value=data_trans["value"], color=link_colors,
                  customdata=hover_text, hovertemplate="%{customdata}<extra></extra>")
    )
    fig = go.Figure(sankey)
    fig.update_layout(font_size=label_size)
    return fig

########## BUILD DASH APP ##########

app = dash.Dash(__name__)
app.layout = html.Div([
    # Title
    html.H3("Electricity, Heat & Hydrogen Sankey Diagram",
            style={"text-align": "center", "margin-bottom": "0px"}),
    # Display data and graph options
    html.Div([
        html.Label("Select Scenario:"),
        dcc.Dropdown(id="scenario-dropdown",
                     options=[{"label": s, "value": s} for s in df["Scenario"].unique()],
                     value=df["Scenario"].unique()[0],
                     style={"margin-bottom": "20px"}), # Reduce spacing
        html.Label("Select Transformation:"),
        dcc.Dropdown(id="transformation-dropdown",
                     options=[{"label": t.capitalize(), "value": t} for t in transformation_types],
                     value="original",
                     style={"margin-bottom": "20px"}), # Reduce spacing
        html.Label("Adjust Flow Opacity:"),
        dcc.Slider(id='slider', min=0, max=1, value=0.5, step=0.1,
                   marks={i/10: str(i/10) for i in range(0, 11)},
                   tooltip={"placement": "bottom", "always_visible": True}),
        html.Label("Adjust Node Label Size:"),
        dcc.Slider(id='label-size-slider', min=20, max=60, value=15, step=1,
                   marks={i: str(i) for i in range(20, 61)}),
        html.Br(),
        dcc.Graph(id="sankey-graph", style={"width": "100%", "height": "500px"}),

        # Legend, set to be closer to the graph
        html.Div([
            html.Div(style={"width": "20px", "height": "20px", "background-color": "rgba(0, 158, 115, 0.5)", "margin-right": "10px"}),
            html.Span("Electricity flow (kWh)", style={"font-size": "14px", "margin-right": "10px"}),
            html.Div(style={"width": "20px", "height": "20px", "background-color": "rgba(136, 34, 85, 0.5)", "margin-right": "10px"}),
            html.Span("Heat flow (MJ)", style={"font-size": "14px", "margin-right": "10px"}),
            html.Div(style={"width": "20px", "height": "20px", "background-color": "rgba(0, 95, 153, 0.5)", "margin-right": "10px"}),
            html.Span("H\u2082 flow (kg)", style={"font-size": "14px", "margin-right": "10px"}) # H₂ with subscript
        ], style={"display": "flex", "justify-content": "center", "margin-top": "10px"}),
        html.Br(),

        # Buttons for saving sankey diagram
        html.Button("Save as 600 DPI PNG", id="save-png-btn", n_clicks=0, style={"margin-right": "10px"}),
        html.Button("Save as PDF", id="save-pdf-btn", n_clicks=0),
        html.Div(id="save-message", style={"margin-top": "10px", "font-weight": "bold", "color": "#444"})
    ], style={"width": "60%", "margin": "0 auto"})
])

# Wire the update of everything
@app.callback(
    Output("sankey-graph", "figure"),
    Input("scenario-dropdown", "value"),
    Input("transformation-dropdown", "value"),
    Input("slider", "value"),
    Input("label-size-slider", "value")
)

def update_sankey(selected_scenario, selected_transformation, opacity, label_size):
    return create_sankey_figure(selected_scenario, selected_transformation, opacity=opacity, label_size=label_size)

@app.callback(
    Output("save-message", "children"),
    Input("save-png-btn", "n_clicks"),
    Input("save-pdf-btn", "n_clicks"),
    State("scenario-dropdown", "value"),
    State("transformation-dropdown", "value"),
    State("slider", "value"),
    State("label-size-slider", "value"),
    prevent_initial_call=True
)

# Saving figure options
def save_figure(png_clicks, pdf_clicks, scenario, transformation, opacity, label_size):
    ctx = dash.callback_context
    if not ctx.triggered:
        raise dash.exceptions.PreventUpdate

    button_id = ctx.triggered[0]["prop_id"].split(".")[0]
    fig = create_sankey_figure(scenario, transformation, opacity=opacity, label_size=label_size)
    filename_base = f"sankey_{scenario}_{transformation}".replace(" ", "_").lower()

    width = 1920
    height = int(width * 9 / 17)
    scale = 3.125  # This gives 600 DPI for print quality

    try:
        if button_id == "save-png-btn":
            fig.write_image(f"{filename_base}.png", width=width, height=height, scale=scale)
            return f"PNG saved as {filename_base}.png"
        elif button_id == "save-pdf-btn":
            fig.write_image(f"{filename_base}.pdf", width=width, height=height)
            return f"PDF saved as {filename_base}.pdf"
    except Exception as e:
        return f"Error saving file: {str(e)}"

# Run
if __name__ == '__main__':
    app.run_server(debug=True, port=8060)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8060/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <div style="border: 2px solid #FFA500; padding: 10px; border-radius: 5px; background-color: #FFFACD; color: black; text-align: center;">
#   <h2 style="margin: 0;">Display concatenated Dataframe for the Sankey Diagrams</h2>
# </div>

# %% [markdown]
# **You need to have run the precedent "*Combining all Electricity / H<sub>2</sub> / Heat flows in Sankey diagrams*" cell of the notebook**

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    display(df)
# Out:
#     Scenario   Source   Target      Value FlowType
# 0    SIM01v2  ICE-CHP     LOAD  3.008e+04     elec
# 1    SIM01v2  ICE-CHP       HP  1.301e+04     elec
# 2    SIM01v2  ICE-CHP        P  1.250e-02     elec
# 3    SIM01v2  ICE-CHP      BAT  1.632e+04     elec
# 4    SIM01v2  ICE-CHP    PEMEL  2.583e+04     elec
# 5    SIM01v2  ICE-CHP  H2C/H2S  2.398e+03     elec
# 6    SIM01v2  ICE-CHP     GRID  5.243e+04     elec
# 7    SIM01v2       WT     LOAD  2.696e+04     elec
# 8    SIM01v2       WT       HP  9.374e+03     elec
# 9    SIM01v2       WT        P  6.475e-03     elec
# 10   SIM01v2       WT      BAT  3.163e+04     elec
# 11   SIM01v2       WT    PEMEL  1.086e+05     elec
# 12   SIM01v2       WT  H2C/H2S  1.008e+04     elec
# 13   SIM01v2       WT     GRID  2.270e+05     elec
# 14   SIM01v2       PV     LOAD  1.736e+05     elec
# 15   SIM01v2       PV       HP  2.537e+04     elec
# 16   SIM01v2       PV        P  1.726e-02     elec
# 17   SIM01v2       PV      BAT  1.597e+05     elec
# 18   SIM01v2       PV    PEMEL  9.550e+05     elec
# 19   SIM01v2       PV  H2C/H2S  8.868e+04     elec
# 20   SIM01v2       PV     GRID  1.869e+08     elec
# 21   SIM01v2      BAT     LOAD  3.166e+04     elec
# 22   SIM01v2      BAT       HP  5.223e+03     elec
# 23   SIM01v2      BAT        P  3.505e-03     elec
# 24   SIM01v2      BAT      BAT  0.000e+00     elec
# 25   SIM01v2      BAT    PEMEL  2.358e+04     elec
# 26   SIM01v2      BAT  H2C/H2S  2.190e+03     elec
# 27   SIM01v2      BAT     GRID  1.122e+05     elec
# 28   SIM01v2     GRID     LOAD  3.497e+04     elec
# 29   SIM01v2     GRID       HP  9.594e+03     elec
# 30   SIM01v2     GRID        P  3.638e-03     elec
# 31   SIM01v2     GRID      BAT  3.388e-13     elec
# 32   SIM01v2     GRID    PEMEL  0.000e+00     elec
# 33   SIM01v2     GRID  H2C/H2S  0.000e+00     elec
# 34   SIM01v2     GRID     GRID  0.000e+00     elec
# 35   SIM02v2  ICE-CHP     LOAD  3.107e+04     elec
# 36   SIM02v2  ICE-CHP       HP  1.385e+04     elec
# 37   SIM02v2  ICE-CHP        P  1.301e-02     elec
# 38   SIM02v2  ICE-CHP      BAT  1.678e+04     elec
# 39   SIM02v2  ICE-CHP    PEMEL  2.565e+04     elec
# 40   SIM02v2  ICE-CHP  H2C/H2S  2.382e+03     elec
# 41   SIM02v2  ICE-CHP     GRID  5.444e+04     elec
# 42   SIM02v2       WT     LOAD  2.697e+04     elec
# 43   SIM02v2       WT       HP  9.213e+03     elec
# 44   SIM02v2       WT        P  6.474e-03     elec
# 45   SIM02v2       WT      BAT  3.197e+04     elec
# 46   SIM02v2       WT    PEMEL  1.017e+05     elec
# 47   SIM02v2       WT  H2C/H2S  9.448e+03     elec
# 48   SIM02v2       WT     GRID  2.342e+05     elec
# 49   SIM02v2       PV     LOAD  1.736e+05     elec
# 50   SIM02v2       PV       HP  2.467e+04     elec
# 51   SIM02v2       PV        P  1.726e-02     elec
# 52   SIM02v2       PV      BAT  1.591e+05     elec
# 53   SIM02v2       PV    PEMEL  8.003e+05     elec
# 54   SIM02v2       PV  H2C/H2S  7.432e+04     elec
# 55   SIM02v2       PV     GRID  1.871e+08     elec
# 56   SIM02v2      BAT     LOAD  3.166e+04     elec
# 57   SIM02v2      BAT       HP  5.188e+03     elec
# 58   SIM02v2      BAT        P  3.549e-03     elec
# 59   SIM02v2      BAT      BAT  0.000e+00     elec
# 60   SIM02v2      BAT    PEMEL  2.164e+04     elec
# 61   SIM02v2      BAT  H2C/H2S  2.010e+03     elec
# 62   SIM02v2      BAT     GRID  1.142e+05     elec
# 63   SIM02v2     GRID     LOAD  3.398e+04     elec
# 64   SIM02v2     GRID       HP  7.255e+03     elec
# 65   SIM02v2     GRID        P  3.085e-03     elec
# 66   SIM02v2     GRID      BAT  3.516e-13     elec
# 67   SIM02v2     GRID    PEMEL  0.000e+00     elec
# 68   SIM02v2     GRID  H2C/H2S  0.000e+00     elec
# 69   SIM02v2     GRID     GRID  0.000e+00     elec
# 70   SIM03v2  ICE-CHP     LOAD  3.127e+04     elec
# 71   SIM03v2  ICE-CHP       HP  1.427e+04     elec
# 72   SIM03v2  ICE-CHP        P  1.329e-02     elec
# 73   SIM03v2  ICE-CHP      BAT  1.731e+04     elec
# 74   SIM03v2  ICE-CHP    PEMEL  2.428e+04     elec
# 75   SIM03v2  ICE-CHP  H2C/H2S  2.255e+03     elec
# 76   SIM03v2  ICE-CHP     GRID  5.634e+04     elec
# 77   SIM03v2       WT     LOAD  2.690e+04     elec
# 78   SIM03v2       WT       HP  8.448e+03     elec
# 79   SIM03v2       WT        P  6.380e-03     elec
# 80   SIM03v2       WT      BAT  3.147e+04     elec
# 81   SIM03v2       WT    PEMEL  7.987e+04     elec
# 82   SIM03v2       WT  H2C/H2S  7.416e+03     elec
# 83   SIM03v2       WT     GRID  2.595e+05     elec
# 84   SIM03v2       PV     LOAD  1.736e+05     elec
# 85   SIM03v2       PV       HP  2.486e+04     elec
# 86   SIM03v2       PV        P  1.726e-02     elec
# 87   SIM03v2       PV      BAT  1.591e+05     elec
# 88   SIM03v2       PV    PEMEL  6.859e+05     elec
# 89   SIM03v2       PV  H2C/H2S  6.369e+04     elec
# 90   SIM03v2       PV     GRID  1.872e+08     elec
# 91   SIM03v2      BAT     LOAD  3.165e+04     elec
# 92   SIM03v2      BAT       HP  5.018e+03     elec
# 93   SIM03v2      BAT        P  3.533e-03     elec
# 94   SIM03v2      BAT      BAT  0.000e+00     elec
# 95   SIM03v2      BAT    PEMEL  1.890e+04     elec
# 96   SIM03v2      BAT  H2C/H2S  1.755e+03     elec
# 97   SIM03v2      BAT     GRID  1.174e+05     elec
# 98   SIM03v2     GRID     LOAD  3.385e+04     elec
# 99   SIM03v2     GRID       HP  6.693e+03     elec
# 100  SIM03v2     GRID        P  2.918e-03     elec
# 101  SIM03v2     GRID      BAT  3.700e-13     elec
# 102  SIM03v2     GRID    PEMEL  0.000e+00     elec
# 103  SIM03v2     GRID  H2C/H2S  0.000e+00     elec
# 104  SIM03v2     GRID     GRID  0.000e+00     elec
# 105  SIM04v2  ICE-CHP     LOAD  3.070e+04     elec
# 106  SIM04v2  ICE-CHP       HP  1.337e+04     elec
# 107  SIM04v2  ICE-CHP        P  1.283e-02     elec
# 108  SIM04v2  ICE-CHP      BAT  1.728e+04     elec
# 109  SIM04v2  ICE-CHP    PEMEL  2.064e+04     elec
# 110  SIM04v2  ICE-CHP  H2C/H2S  1.917e+03     elec
# 111  SIM04v2  ICE-CHP     GRID  5.910e+04     elec
# 112  SIM04v2       WT     LOAD  2.683e+04     elec
# 113  SIM04v2       WT       HP  8.500e+03     elec
# 114  SIM04v2       WT        P  6.364e-03     elec
# 115  SIM04v2       WT      BAT  3.133e+04     elec
# 116  SIM04v2       WT    PEMEL  6.353e+04     elec
# 117  SIM04v2       WT  H2C/H2S  5.899e+03     elec
# 118  SIM04v2       WT     GRID  2.775e+05     elec
# 119  SIM04v2       PV     LOAD  1.736e+05     elec
# 120  SIM04v2       PV       HP  2.533e+04     elec
# 121  SIM04v2       PV        P  1.726e-02     elec
# 122  SIM04v2       PV      BAT  1.602e+05     elec
# 123  SIM04v2       PV    PEMEL  6.981e+05     elec
# 124  SIM04v2       PV  H2C/H2S  6.483e+04     elec
# 125  SIM04v2       PV     GRID  1.872e+08     elec
# 126  SIM04v2      BAT     LOAD  3.176e+04     elec
# 127  SIM04v2      BAT       HP  5.112e+03     elec
# 128  SIM04v2      BAT        P  3.561e-03     elec
# 129  SIM04v2      BAT      BAT  0.000e+00     elec
# 130  SIM04v2      BAT    PEMEL  1.622e+04     elec
# 131  SIM04v2      BAT  H2C/H2S  1.507e+03     elec
# 132  SIM04v2      BAT     GRID  1.202e+05     elec
# 133  SIM04v2     GRID     LOAD  3.439e+04     elec
# 134  SIM04v2     GRID       HP  8.312e+03     elec
# 135  SIM04v2     GRID        P  3.363e-03     elec
# 136  SIM04v2     GRID      BAT  3.675e-13     elec
# 137  SIM04v2     GRID    PEMEL  0.000e+00     elec
# 138  SIM04v2     GRID  H2C/H2S  0.000e+00     elec
# 139  SIM04v2     GRID     GRID  0.000e+00     elec
# 140  SIM05v2  ICE-CHP     LOAD  2.993e+04     elec
# 141  SIM05v2  ICE-CHP       HP  1.273e+04     elec
# 142  SIM05v2  ICE-CHP        P  1.240e-02     elec
# 143  SIM05v2  ICE-CHP      BAT  1.676e+04     elec
# 144  SIM05v2  ICE-CHP    PEMEL  2.291e+04     elec
# 145  SIM05v2  ICE-CHP  H2C/H2S  2.127e+03     elec
# 146  SIM05v2  ICE-CHP     GRID  5.685e+04     elec
# 147  SIM05v2       WT     LOAD  2.688e+04     elec
# 148  SIM05v2       WT       HP  8.581e+03     elec
# 149  SIM05v2       WT        P  6.380e-03     elec
# 150  SIM05v2       WT      BAT  3.154e+04     elec
# 151  SIM05v2       WT    PEMEL  7.498e+04     elec
# 152  SIM05v2       WT  H2C/H2S  6.963e+03     elec
# 153  SIM05v2       WT     GRID  2.647e+05     elec
# 154  SIM05v2       PV     LOAD  1.736e+05     elec
# 155  SIM05v2       PV       HP  2.531e+04     elec
# 156  SIM05v2       PV        P  1.726e-02     elec
# 157  SIM05v2       PV      BAT  1.601e+05     elec
# 158  SIM05v2       PV    PEMEL  6.649e+05     elec
# 159  SIM05v2       PV  H2C/H2S  6.174e+04     elec
# 160  SIM05v2       PV     GRID  1.872e+08     elec
# 161  SIM05v2      BAT     LOAD  3.197e+04     elec
# 162  SIM05v2      BAT       HP  5.286e+03     elec
# 163  SIM05v2      BAT        P  3.625e-03     elec
# 164  SIM05v2      BAT      BAT  0.000e+00     elec
# 165  SIM05v2      BAT    PEMEL  1.774e+04     elec
# 166  SIM05v2      BAT  H2C/H2S  1.647e+03     elec
# 167  SIM05v2      BAT     GRID  1.184e+05     elec
# 168  SIM05v2     GRID     LOAD  3.491e+04     elec
# 169  SIM05v2     GRID       HP  9.525e+03     elec
# 170  SIM05v2     GRID        P  3.713e-03     elec
# 171  SIM05v2     GRID      BAT  3.563e-13     elec
# 172  SIM05v2     GRID    PEMEL  0.000e+00     elec
# 173  SIM05v2     GRID  H2C/H2S  0.000e+00     elec
# 174  SIM05v2     GRID     GRID  0.000e+00     elec
# 175  SIM06v2  ICE-CHP     LOAD  2.819e+04     elec
# 176  SIM06v2  ICE-CHP       HP  1.116e+04     elec
# 177  SIM06v2  ICE-CHP        P  1.138e-02     elec
# 178  SIM06v2  ICE-CHP      BAT  1.584e+04     elec
# 179  SIM06v2  ICE-CHP    PEMEL  2.509e+04     elec
# 180  SIM06v2  ICE-CHP  H2C/H2S  2.330e+03     elec
# 181  SIM06v2  ICE-CHP     GRID  5.697e+04     elec
# 182  SIM06v2       WT     LOAD  2.690e+04     elec
# 183  SIM06v2       WT       HP  8.761e+03     elec
# 184  SIM06v2       WT        P  6.399e-03     elec
# 185  SIM06v2       WT      BAT  3.174e+04     elec
# 186  SIM06v2       WT    PEMEL  7.375e+04     elec
# 187  SIM06v2       WT  H2C/H2S  6.848e+03     elec
# 188  SIM06v2       WT     GRID  2.656e+05     elec
# 189  SIM06v2       PV     LOAD  1.736e+05     elec
# 190  SIM06v2       PV       HP  2.403e+04     elec
# 191  SIM06v2       PV        P  1.726e-02     elec
# 192  SIM06v2       PV      BAT  1.612e+05     elec
# 193  SIM06v2       PV    PEMEL  6.397e+05     elec
# 194  SIM06v2       PV  H2C/H2S  5.940e+04     elec
# 195  SIM06v2       PV     GRID  1.872e+08     elec
# 196  SIM06v2      BAT     LOAD  3.193e+04     elec
# 197  SIM06v2      BAT       HP  5.470e+03     elec
# 198  SIM06v2      BAT        P  3.673e-03     elec
# 199  SIM06v2      BAT      BAT  0.000e+00     elec
# 200  SIM06v2      BAT    PEMEL  1.950e+04     elec
# 201  SIM06v2      BAT  H2C/H2S  1.810e+03     elec
# 202  SIM06v2      BAT     GRID  1.160e+05     elec
# 203  SIM06v2     GRID     LOAD  3.665e+04     elec
# 204  SIM06v2     GRID       HP  1.291e+04     elec
# 205  SIM06v2     GRID        P  4.671e-03     elec
# 206  SIM06v2     GRID      BAT  3.434e-13     elec
# 207  SIM06v2     GRID    PEMEL  0.000e+00     elec
# 208  SIM06v2     GRID  H2C/H2S  0.000e+00     elec
# 209  SIM06v2     GRID     GRID  0.000e+00     elec
# 210  SIM07v2  ICE-CHP     LOAD  8.693e+03     elec
# 211  SIM07v2  ICE-CHP       HP  2.444e+03     elec
# 212  SIM07v2  ICE-CHP        P  2.806e-03     elec
# 213  SIM07v2  ICE-CHP      BAT  3.553e+03     elec
# 214  SIM07v2  ICE-CHP    PEMEL  1.615e+04     elec
# 215  SIM07v2  ICE-CHP  H2C/H2S  1.499e+03     elec
# 216  SIM07v2  ICE-CHP     GRID  5.554e+04     elec
# 217  SIM07v2       WT     LOAD  2.849e+04     elec
# 218  SIM07v2       WT       HP  1.455e+04     elec
# 219  SIM07v2       WT        P  7.222e-03     elec
# 220  SIM07v2       WT      BAT  3.130e+04     elec
# 221  SIM07v2       WT    PEMEL  6.640e+04     elec
# 222  SIM07v2       WT  H2C/H2S  6.166e+03     elec
# 223  SIM07v2       WT     GRID  2.667e+05     elec
# 224  SIM07v2       PV     LOAD  1.737e+05     elec
# 225  SIM07v2       PV       HP  2.402e+04     elec
# 226  SIM07v2       PV        P  1.726e-02     elec
# 227  SIM07v2       PV      BAT  1.633e+05     elec
# 228  SIM07v2       PV    PEMEL  4.820e+05     elec
# 229  SIM07v2       PV  H2C/H2S  4.475e+04     elec
# 230  SIM07v2       PV     GRID  1.874e+08     elec
# 231  SIM07v2      BAT     LOAD  3.137e+04     elec
# 232  SIM07v2      BAT       HP  7.488e+03     elec
# 233  SIM07v2      BAT        P  3.494e-03     elec
# 234  SIM07v2      BAT      BAT  0.000e+00     elec
# 235  SIM07v2      BAT    PEMEL  1.384e+04     elec
# 236  SIM07v2      BAT  H2C/H2S  1.285e+03     elec
# 237  SIM07v2      BAT     GRID  1.155e+05     elec
# 238  SIM07v2     GRID     LOAD  5.510e+04     elec
# 239  SIM07v2     GRID       HP  3.915e+04     elec
# 240  SIM07v2     GRID        P  1.259e-02     elec
# 241  SIM07v2     GRID      BAT  1.510e-13     elec
# 242  SIM07v2     GRID    PEMEL  0.000e+00     elec
# 243  SIM07v2     GRID  H2C/H2S  0.000e+00     elec
# 244  SIM07v2     GRID     GRID  0.000e+00     elec
# 245  SIM08v2  ICE-CHP     LOAD  1.694e+04     elec
# 246  SIM08v2  ICE-CHP       HP  3.499e+03     elec
# 247  SIM08v2  ICE-CHP        P  4.264e-03     elec
# 248  SIM08v2  ICE-CHP      BAT  6.510e+03     elec
# 249  SIM08v2  ICE-CHP    PEMEL  7.149e+03     elec
# 250  SIM08v2  ICE-CHP  H2C/H2S  6.638e+02     elec
# 251  SIM08v2  ICE-CHP     GRID  1.306e+02     elec
# 252  SIM08v2       WT     LOAD  9.149e+04     elec
# 253  SIM08v2       WT       HP  3.351e+04     elec
# 254  SIM08v2       WT        P  1.334e-02     elec
# 255  SIM08v2       WT      BAT  7.729e+04     elec
# 256  SIM08v2       WT    PEMEL  1.902e+05     elec
# 257  SIM08v2       WT  H2C/H2S  1.766e+04     elec
# 258  SIM08v2       WT     GRID  3.473e+03     elec
# 259  SIM08v2       PV     LOAD  0.000e+00     elec
# 260  SIM08v2       PV       HP  0.000e+00     elec
# 261  SIM08v2       PV        P  0.000e+00     elec
# 262  SIM08v2       PV      BAT  0.000e+00     elec
# 263  SIM08v2       PV    PEMEL  0.000e+00     elec
# 264  SIM08v2       PV  H2C/H2S  0.000e+00     elec
# 265  SIM08v2       PV     GRID  0.000e+00     elec
# 266  SIM08v2      BAT     LOAD  1.745e+04     elec
# 267  SIM08v2      BAT       HP  5.197e+03     elec
# 268  SIM08v2      BAT        P  2.336e-03     elec
# 269  SIM08v2      BAT      BAT  0.000e+00     elec
# 270  SIM08v2      BAT    PEMEL  3.390e+04     elec
# 271  SIM08v2      BAT  H2C/H2S  3.148e+03     elec
# 272  SIM08v2      BAT     GRID  6.189e+02     elec
# 273  SIM08v2     GRID     LOAD  1.714e+05     elec
# 274  SIM08v2     GRID       HP  7.014e+04     elec
# 275  SIM08v2     GRID        P  2.344e-02     elec
# 276  SIM08v2     GRID      BAT  2.621e-13     elec
# 277  SIM08v2     GRID    PEMEL  0.000e+00     elec
# 278  SIM08v2     GRID  H2C/H2S  0.000e+00     elec
# 279  SIM08v2     GRID     GRID  0.000e+00     elec
# 280  SIM09v2  ICE-CHP     LOAD  1.619e+04     elec
# 281  SIM09v2  ICE-CHP       HP  4.519e+03     elec
# 282  SIM09v2  ICE-CHP        P  4.722e-03     elec
# 283  SIM09v2  ICE-CHP      BAT  6.757e+03     elec
# 284  SIM09v2  ICE-CHP    PEMEL  1.055e+04     elec
# 285  SIM09v2  ICE-CHP  H2C/H2S  9.796e+02     elec
# 286  SIM09v2  ICE-CHP     GRID  1.927e+02     elec
# 287  SIM09v2       WT     LOAD  9.071e+04     elec
# 288  SIM09v2       WT       HP  3.172e+04     elec
# 289  SIM09v2       WT        P  1.323e-02     elec
# 290  SIM09v2       WT      BAT  7.593e+04     elec
# 291  SIM09v2       WT    PEMEL  1.937e+05     elec
# 292  SIM09v2       WT  H2C/H2S  1.799e+04     elec
# 293  SIM09v2       WT     GRID  3.537e+03     elec
# 294  SIM09v2       PV     LOAD  0.000e+00     elec
# 295  SIM09v2       PV       HP  0.000e+00     elec
# 296  SIM09v2       PV        P  0.000e+00     elec
# 297  SIM09v2       PV      BAT  0.000e+00     elec
# 298  SIM09v2       PV    PEMEL  0.000e+00     elec
# 299  SIM09v2       PV  H2C/H2S  0.000e+00     elec
# 300  SIM09v2       PV     GRID  0.000e+00     elec
# 301  SIM09v2      BAT     LOAD  1.769e+04     elec
# 302  SIM09v2      BAT       HP  4.682e+03     elec
# 303  SIM09v2      BAT        P  2.211e-03     elec
# 304  SIM09v2      BAT      BAT  0.000e+00     elec
# 305  SIM09v2      BAT    PEMEL  3.341e+04     elec
# 306  SIM09v2      BAT  H2C/H2S  3.103e+03     elec
# 307  SIM09v2      BAT     GRID  6.100e+02     elec
# 308  SIM09v2     GRID     LOAD  1.727e+05     elec
# 309  SIM09v2     GRID       HP  6.930e+04     elec
# 310  SIM09v2     GRID        P  2.322e-02     elec
# 311  SIM09v2     GRID      BAT  2.310e-13     elec
# 312  SIM09v2     GRID    PEMEL  0.000e+00     elec
# 313  SIM09v2     GRID  H2C/H2S  0.000e+00     elec
# 314  SIM09v2     GRID     GRID  0.000e+00     elec
# 315  SIM10v2  ICE-CHP     LOAD  1.408e+04     elec
# 316  SIM10v2  ICE-CHP       HP  2.868e+03     elec
# 317  SIM10v2  ICE-CHP        P  3.470e-03     elec
# 318  SIM10v2  ICE-CHP      BAT  6.593e+03     elec
# 319  SIM10v2  ICE-CHP    PEMEL  1.544e+04     elec
# 320  SIM10v2  ICE-CHP  H2C/H2S  1.434e+03     elec
# 321  SIM10v2  ICE-CHP     GRID  2.822e+02     elec
# 322  SIM10v2       WT     LOAD  8.990e+04     elec
# 323  SIM10v2       WT       HP  2.774e+04     elec
# 324  SIM10v2       WT        P  1.289e-02     elec
# 325  SIM10v2       WT      BAT  7.350e+04     elec
# 326  SIM10v2       WT    PEMEL  2.002e+05     elec
# 327  SIM10v2       WT  H2C/H2S  1.859e+04     elec
# 328  SIM10v2       WT     GRID  3.656e+03     elec
# 329  SIM10v2       PV     LOAD  0.000e+00     elec
# 330  SIM10v2       PV       HP  0.000e+00     elec
# 331  SIM10v2       PV        P  0.000e+00     elec
# 332  SIM10v2       PV      BAT  0.000e+00     elec
# 333  SIM10v2       PV    PEMEL  0.000e+00     elec
# 334  SIM10v2       PV  H2C/H2S  0.000e+00     elec
# 335  SIM10v2       PV     GRID  0.000e+00     elec
# 336  SIM10v2      BAT     LOAD  1.738e+04     elec
# 337  SIM10v2      BAT       HP  4.463e+03     elec
# 338  SIM10v2      BAT        P  2.226e-03     elec
# 339  SIM10v2      BAT      BAT  0.000e+00     elec
# 340  SIM10v2      BAT    PEMEL  3.309e+04     elec
# 341  SIM10v2      BAT  H2C/H2S  3.072e+03     elec
# 342  SIM10v2      BAT     GRID  6.040e+02     elec
# 343  SIM10v2     GRID     LOAD  1.760e+05     elec
# 344  SIM10v2     GRID       HP  7.415e+04     elec
# 345  SIM10v2     GRID        P  2.480e-02     elec
# 346  SIM10v2     GRID      BAT  2.385e-13     elec
# 347  SIM10v2     GRID    PEMEL  0.000e+00     elec
# 348  SIM10v2     GRID  H2C/H2S  0.000e+00     elec
# 349  SIM10v2     GRID     GRID  0.000e+00     elec
# 350  SIM11v2  ICE-CHP     LOAD  1.241e+04     elec
# 351  SIM11v2  ICE-CHP       HP  2.661e+03     elec
# 352  SIM11v2  ICE-CHP        P  3.229e-03     elec
# 353  SIM11v2  ICE-CHP      BAT  6.432e+03     elec
# 354  SIM11v2  ICE-CHP    PEMEL  1.599e+04     elec
# 355  SIM11v2  ICE-CHP  H2C/H2S  1.485e+03     elec
# 356  SIM11v2  ICE-CHP     GRID  2.920e+02     elec
# 357  SIM11v2       WT     LOAD  9.005e+04     elec
# 358  SIM11v2       WT       HP  2.743e+04     elec
# 359  SIM11v2       WT        P  1.286e-02     elec
# 360  SIM11v2       WT      BAT  7.317e+04     elec
# 361  SIM11v2       WT    PEMEL  1.892e+05     elec
# 362  SIM11v2       WT  H2C/H2S  1.757e+04     elec
# 363  SIM11v2       WT     GRID  1.617e+04     elec
# 364  SIM11v2       PV     LOAD  0.000e+00     elec
# 365  SIM11v2       PV       HP  0.000e+00     elec
# 366  SIM11v2       PV        P  0.000e+00     elec
# 367  SIM11v2       PV      BAT  0.000e+00     elec
# 368  SIM11v2       PV    PEMEL  0.000e+00     elec
# 369  SIM11v2       PV  H2C/H2S  0.000e+00     elec
# 370  SIM11v2       PV     GRID  0.000e+00     elec
# 371  SIM11v2      BAT     LOAD  1.694e+04     elec
# 372  SIM11v2      BAT       HP  4.253e+03     elec
# 373  SIM11v2      BAT        P  2.124e-03     elec
# 374  SIM11v2      BAT      BAT  0.000e+00     elec
# 375  SIM11v2      BAT    PEMEL  3.024e+04     elec
# 376  SIM11v2      BAT  H2C/H2S  2.808e+03     elec
# 377  SIM11v2      BAT     GRID  2.824e+03     elec
# 378  SIM11v2     GRID     LOAD  1.779e+05     elec
# 379  SIM11v2     GRID       HP  7.545e+04     elec
# 380  SIM11v2     GRID        P  2.516e-02     elec
# 381  SIM11v2     GRID      BAT  2.824e-13     elec
# 382  SIM11v2     GRID    PEMEL  0.000e+00     elec
# 383  SIM11v2     GRID  H2C/H2S  0.000e+00     elec
# 384  SIM11v2     GRID     GRID  0.000e+00     elec
# 385  SIM12v2  ICE-CHP     LOAD  1.099e+04     elec
# 386  SIM12v2  ICE-CHP       HP  2.438e+03     elec
# 387  SIM12v2  ICE-CHP        P  2.783e-03     elec
# 388  SIM12v2  ICE-CHP      BAT  5.588e+03     elec
# 389  SIM12v2  ICE-CHP    PEMEL  1.586e+04     elec
# 390  SIM12v2  ICE-CHP  H2C/H2S  1.473e+03     elec
# 391  SIM12v2  ICE-CHP     GRID  3.736e+02     elec
# 392  SIM12v2       WT     LOAD  9.027e+04     elec
# 393  SIM12v2       WT       HP  2.733e+04     elec
# 394  SIM12v2       WT        P  1.292e-02     elec
# 395  SIM12v2       WT      BAT  7.275e+04     elec
# 396  SIM12v2       WT    PEMEL  1.760e+05     elec
# 397  SIM12v2       WT  H2C/H2S  1.635e+04     elec
# 398  SIM12v2       WT     GRID  3.087e+04     elec
# 399  SIM12v2       PV     LOAD  0.000e+00     elec
# 400  SIM12v2       PV       HP  0.000e+00     elec
# 401  SIM12v2       PV        P  0.000e+00     elec
# 402  SIM12v2       PV      BAT  0.000e+00     elec
# 403  SIM12v2       PV    PEMEL  0.000e+00     elec
# 404  SIM12v2       PV  H2C/H2S  0.000e+00     elec
# 405  SIM12v2       PV     GRID  0.000e+00     elec
# 406  SIM12v2      BAT     LOAD  1.717e+04     elec
# 407  SIM12v2      BAT       HP  4.077e+03     elec
# 408  SIM12v2      BAT        P  2.029e-03     elec
# 409  SIM12v2      BAT      BAT  0.000e+00     elec
# 410  SIM12v2      BAT    PEMEL  2.739e+04     elec
# 411  SIM12v2      BAT  H2C/H2S  2.543e+03     elec
# 412  SIM12v2      BAT     GRID  5.258e+03     elec
# 413  SIM12v2     GRID     LOAD  1.789e+05     elec
# 414  SIM12v2     GRID       HP  7.694e+04     elec
# 415  SIM12v2     GRID        P  2.565e-02     elec
# 416  SIM12v2     GRID      BAT  2.592e-13     elec
# 417  SIM12v2     GRID    PEMEL  0.000e+00     elec
# 418  SIM12v2     GRID  H2C/H2S  0.000e+00     elec
# 419  SIM12v2     GRID     GRID  0.000e+00     elec
# 420  SIM13v2  ICE-CHP     LOAD  8.079e+03     elec
# 421  SIM13v2  ICE-CHP       HP  1.807e+03     elec
# 422  SIM13v2  ICE-CHP        P  2.051e-03     elec
# 423  SIM13v2  ICE-CHP      BAT  4.521e+03     elec
# 424  SIM13v2  ICE-CHP    PEMEL  1.640e+04     elec
# 425  SIM13v2  ICE-CHP  H2C/H2S  1.523e+03     elec
# 426  SIM13v2  ICE-CHP     GRID  8.282e+02     elec
# 427  SIM13v2       WT     LOAD  9.027e+04     elec
# 428  SIM13v2       WT       HP  2.724e+04     elec
# 429  SIM13v2       WT        P  1.295e-02     elec
# 430  SIM13v2       WT      BAT  7.100e+04     elec
# 431  SIM13v2       WT    PEMEL  1.576e+05     elec
# 432  SIM13v2       WT  H2C/H2S  1.464e+04     elec
# 433  SIM13v2       WT     GRID  5.284e+04     elec
# 434  SIM13v2       PV     LOAD  0.000e+00     elec
# 435  SIM13v2       PV       HP  0.000e+00     elec
# 436  SIM13v2       PV        P  0.000e+00     elec
# 437  SIM13v2       PV      BAT  0.000e+00     elec
# 438  SIM13v2       PV    PEMEL  0.000e+00     elec
# 439  SIM13v2       PV  H2C/H2S  0.000e+00     elec
# 440  SIM13v2       PV     GRID  0.000e+00     elec
# 441  SIM13v2      BAT     LOAD  1.637e+04     elec
# 442  SIM13v2      BAT       HP  4.080e+03     elec
# 443  SIM13v2      BAT        P  1.968e-03     elec
# 444  SIM13v2      BAT      BAT  0.000e+00     elec
# 445  SIM13v2      BAT    PEMEL  2.367e+04     elec
# 446  SIM13v2      BAT  H2C/H2S  2.198e+03     elec
# 447  SIM13v2      BAT     GRID  8.382e+03     elec
# 448  SIM13v2     GRID     LOAD  1.826e+05     elec
# 449  SIM13v2     GRID       HP  7.918e+04     elec
# 450  SIM13v2     GRID        P  2.641e-02     elec
# 451  SIM13v2     GRID      BAT  2.478e-13     elec
# 452  SIM13v2     GRID    PEMEL  0.000e+00     elec
# 453  SIM13v2     GRID  H2C/H2S  0.000e+00     elec
# 454  SIM13v2     GRID     GRID  0.000e+00     elec
# 455  SIM14v2  ICE-CHP     LOAD  3.173e+03     elec
# 456  SIM14v2  ICE-CHP       HP  9.847e+02     elec
# 457  SIM14v2  ICE-CHP        P  1.061e-03     elec
# 458  SIM14v2  ICE-CHP      BAT  2.084e+03     elec
# 459  SIM14v2  ICE-CHP    PEMEL  1.406e+04     elec
# 460  SIM14v2  ICE-CHP  H2C/H2S  1.306e+03     elec
# 461  SIM14v2  ICE-CHP     GRID  2.321e+03     elec
# 462  SIM14v2       WT     LOAD  9.166e+04     elec
# 463  SIM14v2       WT       HP  2.972e+04     elec
# 464  SIM14v2       WT        P  1.330e-02     elec
# 465  SIM14v2       WT      BAT  7.008e+04     elec
# 466  SIM14v2       WT    PEMEL  1.109e+05     elec
# 467  SIM14v2       WT  H2C/H2S  1.030e+04     elec
# 468  SIM14v2       WT     GRID  1.009e+05     elec
# 469  SIM14v2       PV     LOAD  0.000e+00     elec
# 470  SIM14v2       PV       HP  0.000e+00     elec
# 471  SIM14v2       PV        P  0.000e+00     elec
# 472  SIM14v2       PV      BAT  0.000e+00     elec
# 473  SIM14v2       PV    PEMEL  0.000e+00     elec
# 474  SIM14v2       PV  H2C/H2S  0.000e+00     elec
# 475  SIM14v2       PV     GRID  0.000e+00     elec
# 476  SIM14v2      BAT     LOAD  1.543e+04     elec
# 477  SIM14v2      BAT       HP  3.856e+03     elec
# 478  SIM14v2      BAT        P  1.772e-03     elec
# 479  SIM14v2      BAT      BAT  0.000e+00     elec
# 480  SIM14v2      BAT    PEMEL  1.719e+04     elec
# 481  SIM14v2      BAT  H2C/H2S  1.597e+03     elec
# 482  SIM14v2      BAT     GRID  1.394e+04     elec
# 483  SIM14v2     GRID     LOAD  1.871e+05     elec
# 484  SIM14v2     GRID       HP  8.190e+04     elec
# 485  SIM14v2     GRID        P  2.725e-02     elec
# 486  SIM14v2     GRID      BAT  1.810e-13     elec
# 487  SIM14v2     GRID    PEMEL  0.000e+00     elec
# 488  SIM14v2     GRID  H2C/H2S  0.000e+00     elec
# 489  SIM14v2     GRID     GRID  0.000e+00     elec
# 490  SIM15v2  ICE-CHP     LOAD  3.826e+04     elec
# 491  SIM15v2  ICE-CHP       HP  1.693e+04     elec
# 492  SIM15v2  ICE-CHP        P  1.639e-02     elec
# 493  SIM15v2  ICE-CHP      BAT  1.486e+04     elec
# 494  SIM15v2  ICE-CHP    PEMEL  1.494e+04     elec
# 495  SIM15v2  ICE-CHP  H2C/H2S  1.387e+03     elec
# 496  SIM15v2  ICE-CHP     GRID  5.324e+04     elec
# 497  SIM15v2       WT     LOAD  2.117e-01     elec
# 498  SIM15v2       WT       HP  7.493e-02     elec
# 499  SIM15v2       WT        P  5.757e-08     elec
# 500  SIM15v2       WT      BAT  4.381e-02     elec
# 501  SIM15v2       WT    PEMEL  5.622e-02     elec
# 502  SIM15v2       WT  H2C/H2S  5.220e-03     elec
# 503  SIM15v2       WT     GRID  4.353e-01     elec
# 504  SIM15v2       PV     LOAD  1.757e+05     elec
# 505  SIM15v2       PV       HP  2.580e+04     elec
# 506  SIM15v2       PV        P  1.748e-02     elec
# 507  SIM15v2       PV      BAT  1.680e+05     elec
# 508  SIM15v2       PV    PEMEL  1.051e+06     elec
# 509  SIM15v2       PV  H2C/H2S  9.761e+04     elec
# 510  SIM15v2       PV     GRID  3.751e+08     elec
# 511  SIM15v2      BAT     LOAD  3.663e+04     elec
# 512  SIM15v2      BAT       HP  5.332e+03     elec
# 513  SIM15v2      BAT        P  3.707e-03     elec
# 514  SIM15v2      BAT      BAT  0.000e+00     elec
# 515  SIM15v2      BAT    PEMEL  1.095e+04     elec
# 516  SIM15v2      BAT  H2C/H2S  1.017e+03     elec
# 517  SIM15v2      BAT     GRID  1.090e+05     elec
# 518  SIM15v2     GRID     LOAD  4.676e+04     elec
# 519  SIM15v2     GRID       HP  1.473e+04     elec
# 520  SIM15v2     GRID        P  5.796e-03     elec
# 521  SIM15v2     GRID      BAT  1.018e-13     elec
# 522  SIM15v2     GRID    PEMEL  0.000e+00     elec
# 523  SIM15v2     GRID  H2C/H2S  0.000e+00     elec
# 524  SIM15v2     GRID     GRID  0.000e+00     elec
# 525  SIM16v2  ICE-CHP     LOAD  3.851e+04     elec
# 526  SIM16v2  ICE-CHP       HP  1.699e+04     elec
# 527  SIM16v2  ICE-CHP        P  1.641e-02     elec
# 528  SIM16v2  ICE-CHP      BAT  1.522e+04     elec
# 529  SIM16v2  ICE-CHP    PEMEL  1.415e+04     elec
# 530  SIM16v2  ICE-CHP  H2C/H2S  1.314e+03     elec
# 531  SIM16v2  ICE-CHP     GRID  5.403e+04     elec
# 532  SIM16v2       WT     LOAD  2.113e-01     elec
# 533  SIM16v2       WT       HP  8.264e-02     elec
# 534  SIM16v2       WT        P  5.752e-08     elec
# 535  SIM16v2       WT      BAT  4.158e-02     elec
# 536  SIM16v2       WT    PEMEL  5.023e-02     elec
# 537  SIM16v2       WT  H2C/H2S  4.664e-03     elec
# 538  SIM16v2       WT     GRID  4.368e-01     elec
# 539  SIM16v2       PV     LOAD  1.757e+05     elec
# 540  SIM16v2       PV       HP  2.562e+04     elec
# 541  SIM16v2       PV        P  1.748e-02     elec
# 542  SIM16v2       PV      BAT  1.678e+05     elec
# 543  SIM16v2       PV    PEMEL  8.696e+05     elec
# 544  SIM16v2       PV  H2C/H2S  8.075e+04     elec
# 545  SIM16v2       PV     GRID  3.753e+08     elec
# 546  SIM16v2      BAT     LOAD  3.666e+04     elec
# 547  SIM16v2      BAT       HP  5.318e+03     elec
# 548  SIM16v2      BAT        P  3.707e-03     elec
# 549  SIM16v2      BAT      BAT  0.000e+00     elec
# 550  SIM16v2      BAT    PEMEL  1.052e+04     elec
# 551  SIM16v2      BAT  H2C/H2S  9.771e+02     elec
# 552  SIM16v2      BAT     GRID  1.095e+05     elec
# 553  SIM16v2     GRID     LOAD  4.648e+04     elec
# 554  SIM16v2     GRID       HP  1.398e+04     elec
# 555  SIM16v2     GRID        P  5.781e-03     elec
# 556  SIM16v2     GRID      BAT  1.105e-13     elec
# 557  SIM16v2     GRID    PEMEL  0.000e+00     elec
# 558  SIM16v2     GRID  H2C/H2S  0.000e+00     elec
# 559  SIM16v2     GRID     GRID  0.000e+00     elec
# 560  SIM17v2  ICE-CHP     LOAD  3.910e+04     elec
# 561  SIM17v2  ICE-CHP       HP  1.766e+04     elec
# 562  SIM17v2  ICE-CHP        P  1.693e-02     elec
# 563  SIM17v2  ICE-CHP      BAT  1.595e+04     elec
# 564  SIM17v2  ICE-CHP    PEMEL  1.363e+04     elec
# 565  SIM17v2  ICE-CHP  H2C/H2S  1.266e+03     elec
# 566  SIM17v2  ICE-CHP     GRID  5.120e+04     elec
# 567  SIM17v2       WT     LOAD  2.111e-01     elec
# 568  SIM17v2       WT       HP  7.327e-02     elec
# 569  SIM17v2       WT        P  5.743e-08     elec
# 570  SIM17v2       WT      BAT  4.679e-02     elec
# 571  SIM17v2       WT    PEMEL  4.984e-02     elec
# 572  SIM17v2       WT  H2C/H2S  4.628e-03     elec
# 573  SIM17v2       WT     GRID  4.416e-01     elec
# 574  SIM17v2       PV     LOAD  1.757e+05     elec
# 575  SIM17v2       PV       HP  2.715e+04     elec
# 576  SIM17v2       PV        P  1.749e-02     elec
# 577  SIM17v2       PV      BAT  1.677e+05     elec
# 578  SIM17v2       PV    PEMEL  7.297e+05     elec
# 579  SIM17v2       PV  H2C/H2S  6.776e+04     elec
# 580  SIM17v2       PV     GRID  3.754e+08     elec
# 581  SIM17v2      BAT     LOAD  3.636e+04     elec
# 582  SIM17v2      BAT       HP  5.252e+03     elec
# 583  SIM17v2      BAT        P  3.647e-03     elec
# 584  SIM17v2      BAT      BAT  0.000e+00     elec
# 585  SIM17v2      BAT    PEMEL  9.858e+03     elec
# 586  SIM17v2      BAT  H2C/H2S  9.154e+02     elec
# 587  SIM17v2      BAT     GRID  1.107e+05     elec
# 588  SIM17v2     GRID     LOAD  4.619e+04     elec
# 589  SIM17v2     GRID       HP  1.250e+04     elec
# 590  SIM17v2     GRID        P  5.314e-03     elec
# 591  SIM17v2     GRID      BAT  1.165e-13     elec
# 592  SIM17v2     GRID    PEMEL  0.000e+00     elec
# 593  SIM17v2     GRID  H2C/H2S  0.000e+00     elec
# 594  SIM17v2     GRID     GRID  0.000e+00     elec
# 595  SIM18v2  ICE-CHP     LOAD  3.791e+04     elec
# 596  SIM18v2  ICE-CHP       HP  1.659e+04     elec
# 597  SIM18v2  ICE-CHP        P  1.643e-02     elec
# 598  SIM18v2  ICE-CHP      BAT  1.591e+04     elec
# 599  SIM18v2  ICE-CHP    PEMEL  1.140e+04     elec
# 600  SIM18v2  ICE-CHP  H2C/H2S  1.059e+03     elec
# 601  SIM18v2  ICE-CHP     GRID  5.306e+04     elec
# 602  SIM18v2       WT     LOAD  2.089e-01     elec
# 603  SIM18v2       WT       HP  7.421e-02     elec
# 604  SIM18v2       WT        P  5.674e-08     elec
# 605  SIM18v2       WT      BAT  4.509e-02     elec
# 606  SIM18v2       WT    PEMEL  4.336e-02     elec
# 607  SIM18v2       WT  H2C/H2S  4.027e-03     elec
# 608  SIM18v2       WT     GRID  4.516e-01     elec
# 609  SIM18v2       PV     LOAD  1.757e+05     elec
# 610  SIM18v2       PV       HP  2.769e+04     elec
# 611  SIM18v2       PV        P  1.749e-02     elec
# 612  SIM18v2       PV      BAT  1.682e+05     elec
# 613  SIM18v2       PV    PEMEL  7.257e+05     elec
# 614  SIM18v2       PV  H2C/H2S  6.739e+04     elec
# 615  SIM18v2       PV     GRID  3.754e+08     elec
# 616  SIM18v2      BAT     LOAD  3.684e+04     elec
# 617  SIM18v2      BAT       HP  5.434e+03     elec
# 618  SIM18v2      BAT        P  3.769e-03     elec
# 619  SIM18v2      BAT      BAT  0.000e+00     elec
# 620  SIM18v2      BAT    PEMEL  8.333e+03     elec
# 621  SIM18v2      BAT  H2C/H2S  7.738e+02     elec
# 622  SIM18v2      BAT     GRID  1.121e+05     elec
# 623  SIM18v2     GRID     LOAD  4.687e+04     elec
# 624  SIM18v2     GRID       HP  1.438e+04     elec
# 625  SIM18v2     GRID        P  5.691e-03     elec
# 626  SIM18v2     GRID      BAT  1.147e-13     elec
# 627  SIM18v2     GRID    PEMEL  0.000e+00     elec
# 628  SIM18v2     GRID  H2C/H2S  0.000e+00     elec
# 629  SIM18v2     GRID     GRID  0.000e+00     elec
# 630  SIM19v2  ICE-CHP     LOAD  3.658e+04     elec
# 631  SIM19v2  ICE-CHP       HP  1.503e+04     elec
# 632  SIM19v2  ICE-CHP        P  1.552e-02     elec
# 633  SIM19v2  ICE-CHP      BAT  1.513e+04     elec
# 634  SIM19v2  ICE-CHP    PEMEL  1.257e+04     elec
# 635  SIM19v2  ICE-CHP  H2C/H2S  1.167e+03     elec
# 636  SIM19v2  ICE-CHP     GRID  5.284e+04     elec
# 637  SIM19v2       WT     LOAD  2.107e-01     elec
# 638  SIM19v2       WT       HP  7.589e-02     elec
# 639  SIM19v2       WT        P  5.688e-08     elec
# 640  SIM19v2       WT      BAT  4.418e-02     elec
# 641  SIM19v2       WT    PEMEL  4.138e-02     elec
# 642  SIM19v2       WT  H2C/H2S  3.842e-03     elec
# 643  SIM19v2       WT     GRID  4.513e-01     elec
# 644  SIM19v2       PV     LOAD  1.757e+05     elec
# 645  SIM19v2       PV       HP  2.718e+04     elec
# 646  SIM19v2       PV        P  1.748e-02     elec
# 647  SIM19v2       PV      BAT  1.682e+05     elec
# 648  SIM19v2       PV    PEMEL  7.079e+05     elec
# 649  SIM19v2       PV  H2C/H2S  6.574e+04     elec
# 650  SIM19v2       PV     GRID  3.754e+08     elec
# 651  SIM19v2      BAT     LOAD  3.690e+04     elec
# 652  SIM19v2      BAT       HP  5.836e+03     elec
# 653  SIM19v2      BAT        P  3.874e-03     elec
# 654  SIM19v2      BAT      BAT  0.000e+00     elec
# 655  SIM19v2      BAT    PEMEL  8.777e+03     elec
# 656  SIM19v2      BAT  H2C/H2S  8.149e+02     elec
# 657  SIM19v2      BAT     GRID  1.109e+05     elec
# 658  SIM19v2     GRID     LOAD  4.816e+04     elec
# 659  SIM19v2     GRID       HP  1.737e+04     elec
# 660  SIM19v2     GRID        P  6.505e-03     elec
# 661  SIM19v2     GRID      BAT  1.075e-13     elec
# 662  SIM19v2     GRID    PEMEL  0.000e+00     elec
# 663  SIM19v2     GRID  H2C/H2S  0.000e+00     elec
# 664  SIM19v2     GRID     GRID  0.000e+00     elec
# 665  SIM20v2  ICE-CHP     LOAD  3.442e+04     elec
# 666  SIM20v2  ICE-CHP       HP  1.319e+04     elec
# 667  SIM20v2  ICE-CHP        P  1.425e-02     elec
# 668  SIM20v2  ICE-CHP      BAT  1.405e+04     elec
# 669  SIM20v2  ICE-CHP    PEMEL  1.473e+04     elec
# 670  SIM20v2  ICE-CHP  H2C/H2S  1.368e+03     elec
# 671  SIM20v2  ICE-CHP     GRID  5.614e+04     elec
# 672  SIM20v2       WT     LOAD  2.102e-01     elec
# 673  SIM20v2       WT       HP  8.054e-02     elec
# 674  SIM20v2       WT        P  5.684e-08     elec
# 675  SIM20v2       WT      BAT  4.118e-02     elec
# 676  SIM20v2       WT    PEMEL  4.573e-02     elec
# 677  SIM20v2       WT  H2C/H2S  4.246e-03     elec
# 678  SIM20v2       WT     GRID  4.453e-01     elec
# 679  SIM20v2       PV     LOAD  1.757e+05     elec
# 680  SIM20v2       PV       HP  2.439e+04     elec
# 681  SIM20v2       PV        P  1.748e-02     elec
# 682  SIM20v2       PV      BAT  1.692e+05     elec
# 683  SIM20v2       PV    PEMEL  6.861e+05     elec
# 684  SIM20v2       PV  H2C/H2S  6.371e+04     elec
# 685  SIM20v2       PV     GRID  3.755e+08     elec
# 686  SIM20v2      BAT     LOAD  3.684e+04     elec
# 687  SIM20v2      BAT       HP  5.866e+03     elec
# 688  SIM20v2      BAT        P  3.892e-03     elec
# 689  SIM20v2      BAT      BAT  0.000e+00     elec
# 690  SIM20v2      BAT    PEMEL  1.013e+04     elec
# 691  SIM20v2      BAT  H2C/H2S  9.408e+02     elec
# 692  SIM20v2      BAT     GRID  1.093e+05     elec
# 693  SIM20v2     GRID     LOAD  5.039e+04     elec
# 694  SIM20v2     GRID       HP  2.167e+04     elec
# 695  SIM20v2     GRID        P  7.757e-03     elec
# 696  SIM20v2     GRID      BAT  1.001e-13     elec
# 697  SIM20v2     GRID    PEMEL  0.000e+00     elec
# 698  SIM20v2     GRID  H2C/H2S  0.000e+00     elec
# 699  SIM20v2     GRID     GRID  0.000e+00     elec
# 700  SIM21v2  ICE-CHP     LOAD  9.536e+03     elec
# 701  SIM21v2  ICE-CHP       HP  2.497e+03     elec
# 702  SIM21v2  ICE-CHP        P  2.963e-03     elec
# 703  SIM21v2  ICE-CHP      BAT  1.272e+03     elec
# 704  SIM21v2  ICE-CHP    PEMEL  7.010e+03     elec
# 705  SIM21v2  ICE-CHP  H2C/H2S  6.509e+02     elec
# 706  SIM21v2  ICE-CHP     GRID  5.528e+04     elec
# 707  SIM21v2       WT     LOAD  2.083e-01     elec
# 708  SIM21v2       WT       HP  1.470e-01     elec
# 709  SIM21v2       WT        P  5.876e-08     elec
# 710  SIM21v2       WT      BAT  4.238e-03     elec
# 711  SIM21v2       WT    PEMEL  2.288e-02     elec
# 712  SIM21v2       WT  H2C/H2S  2.124e-03     elec
# 713  SIM21v2       WT     GRID  4.427e-01     elec
# 714  SIM21v2       PV     LOAD  1.757e+05     elec
# 715  SIM21v2       PV       HP  2.436e+04     elec
# 716  SIM21v2       PV        P  1.748e-02     elec
# 717  SIM21v2       PV      BAT  1.712e+05     elec
# 718  SIM21v2       PV    PEMEL  5.250e+05     elec
# 719  SIM21v2       PV  H2C/H2S  4.874e+04     elec
# 720  SIM21v2       PV     GRID  3.756e+08     elec
# 721  SIM21v2      BAT     LOAD  3.730e+04     elec
# 722  SIM21v2      BAT       HP  8.757e+03     elec
# 723  SIM21v2      BAT        P  3.950e-03     elec
# 724  SIM21v2      BAT      BAT  0.000e+00     elec
# 725  SIM21v2      BAT    PEMEL  5.153e+03     elec
# 726  SIM21v2      BAT  H2C/H2S  4.785e+02     elec
# 727  SIM21v2      BAT     GRID  1.086e+05     elec
# 728  SIM21v2     GRID     LOAD  7.483e+04     elec
# 729  SIM21v2     GRID       HP  5.730e+04     elec
# 730  SIM21v2     GRID        P  1.899e-02     elec
# 731  SIM21v2     GRID      BAT  7.542e-15     elec
# 732  SIM21v2     GRID    PEMEL  0.000e+00     elec
# 733  SIM21v2     GRID  H2C/H2S  0.000e+00     elec
# 734  SIM21v2     GRID     GRID  0.000e+00     elec
# 735  SIM22v2  ICE-CHP     LOAD  4.370e+04     elec
# 736  SIM22v2  ICE-CHP       HP  1.863e+04     elec
# 737  SIM22v2  ICE-CHP        P  1.848e-02     elec
# 738  SIM22v2  ICE-CHP      BAT  0.000e+00     elec
# 739  SIM22v2  ICE-CHP    PEMEL  2.062e+04     elec
# 740  SIM22v2  ICE-CHP  H2C/H2S  1.915e+03     elec
# 741  SIM22v2  ICE-CHP     GRID  5.475e+04     elec
# 742  SIM22v2       WT     LOAD  2.299e-01     elec
# 743  SIM22v2       WT       HP  8.043e-02     elec
# 744  SIM22v2       WT        P  6.435e-08     elec
# 745  SIM22v2       WT      BAT  0.000e+00     elec
# 746  SIM22v2       WT    PEMEL  7.322e-02     elec
# 747  SIM22v2       WT  H2C/H2S  6.799e-03     elec
# 748  SIM22v2       WT     GRID  4.368e-01     elec
# 749  SIM22v2       PV     LOAD  1.762e+05     elec
# 750  SIM22v2       PV       HP  2.587e+04     elec
# 751  SIM22v2       PV        P  1.753e-02     elec
# 752  SIM22v2       PV      BAT  0.000e+00     elec
# 753  SIM22v2       PV    PEMEL  1.055e+06     elec
# 754  SIM22v2       PV  H2C/H2S  9.794e+04     elec
# 755  SIM22v2       PV     GRID  3.752e+08     elec
# 756  SIM22v2      BAT     LOAD  0.000e+00     elec
# 757  SIM22v2      BAT       HP  0.000e+00     elec
# 758  SIM22v2      BAT        P  0.000e+00     elec
# 759  SIM22v2      BAT      BAT  0.000e+00     elec
# 760  SIM22v2      BAT    PEMEL  0.000e+00     elec
# 761  SIM22v2      BAT  H2C/H2S  0.000e+00     elec
# 762  SIM22v2      BAT     GRID  0.000e+00     elec
# 763  SIM22v2     GRID     LOAD  7.740e+04     elec
# 764  SIM22v2     GRID       HP  1.829e+04     elec
# 765  SIM22v2     GRID        P  7.370e-03     elec
# 766  SIM22v2     GRID      BAT  0.000e+00     elec
# 767  SIM22v2     GRID    PEMEL  0.000e+00     elec
# 768  SIM22v2     GRID  H2C/H2S  0.000e+00     elec
# 769  SIM22v2     GRID     GRID  0.000e+00     elec
# 770  SIM23v2  ICE-CHP     LOAD  4.382e+04     elec
# 771  SIM23v2  ICE-CHP       HP  1.867e+04     elec
# 772  SIM23v2  ICE-CHP        P  1.848e-02     elec
# 773  SIM23v2  ICE-CHP      BAT  0.000e+00     elec
# 774  SIM23v2  ICE-CHP    PEMEL  2.048e+04     elec
# 775  SIM23v2  ICE-CHP  H2C/H2S  1.902e+03     elec
# 776  SIM23v2  ICE-CHP     GRID  5.523e+04     elec
# 777  SIM23v2       WT     LOAD  2.282e-01     elec
# 778  SIM23v2       WT       HP  8.706e-02     elec
# 779  SIM23v2       WT        P  6.336e-08     elec
# 780  SIM23v2       WT      BAT  0.000e+00     elec
# 781  SIM23v2       WT    PEMEL  6.735e-02     elec
# 782  SIM23v2       WT  H2C/H2S  6.253e-03     elec
# 783  SIM23v2       WT     GRID  4.383e-01     elec
# 784  SIM23v2       PV     LOAD  1.762e+05     elec
# 785  SIM23v2       PV       HP  2.567e+04     elec
# 786  SIM23v2       PV        P  1.753e-02     elec
# 787  SIM23v2       PV      BAT  0.000e+00     elec
# 788  SIM23v2       PV    PEMEL  8.727e+05     elec
# 789  SIM23v2       PV  H2C/H2S  8.103e+04     elec
# 790  SIM23v2       PV     GRID  3.754e+08     elec
# 791  SIM23v2      BAT     LOAD  0.000e+00     elec
# 792  SIM23v2      BAT       HP  0.000e+00     elec
# 793  SIM23v2      BAT        P  0.000e+00     elec
# 794  SIM23v2      BAT      BAT  0.000e+00     elec
# 795  SIM23v2      BAT    PEMEL  0.000e+00     elec
# 796  SIM23v2      BAT  H2C/H2S  0.000e+00     elec
# 797  SIM23v2      BAT     GRID  0.000e+00     elec
# 798  SIM23v2     GRID     LOAD  7.727e+04     elec
# 799  SIM23v2     GRID       HP  1.760e+04     elec
# 800  SIM23v2     GRID        P  7.372e-03     elec
# 801  SIM23v2     GRID      BAT  0.000e+00     elec
# 802  SIM23v2     GRID    PEMEL  0.000e+00     elec
# 803  SIM23v2     GRID  H2C/H2S  0.000e+00     elec
# 804  SIM23v2     GRID     GRID  0.000e+00     elec
# 805  SIM24v2  ICE-CHP     LOAD  4.471e+04     elec
# 806  SIM24v2  ICE-CHP       HP  1.979e+04     elec
# 807  SIM24v2  ICE-CHP        P  1.925e-02     elec
# 808  SIM24v2  ICE-CHP      BAT  0.000e+00     elec
# 809  SIM24v2  ICE-CHP    PEMEL  2.071e+04     elec
# 810  SIM24v2  ICE-CHP  H2C/H2S  1.923e+03     elec
# 811  SIM24v2  ICE-CHP     GRID  5.195e+04     elec
# 812  SIM24v2       WT     LOAD  2.302e-01     elec
# 813  SIM24v2       WT       HP  7.799e-02     elec
# 814  SIM24v2       WT        P  6.464e-08     elec
# 815  SIM24v2       WT      BAT  0.000e+00     elec
# 816  SIM24v2       WT    PEMEL  6.842e-02     elec
# 817  SIM24v2       WT  H2C/H2S  6.353e-03     elec
# 818  SIM24v2       WT     GRID  4.443e-01     elec
# 819  SIM24v2       PV     LOAD  1.762e+05     elec
# 820  SIM24v2       PV       HP  2.747e+04     elec
# 821  SIM24v2       PV        P  1.753e-02     elec
# 822  SIM24v2       PV      BAT  0.000e+00     elec
# 823  SIM24v2       PV    PEMEL  7.319e+05     elec
# 824  SIM24v2       PV  H2C/H2S  6.796e+04     elec
# 825  SIM24v2       PV     GRID  3.756e+08     elec
# 826  SIM24v2      BAT     LOAD  0.000e+00     elec
# 827  SIM24v2      BAT       HP  0.000e+00     elec
# 828  SIM24v2      BAT        P  0.000e+00     elec
# 829  SIM24v2      BAT      BAT  0.000e+00     elec
# 830  SIM24v2      BAT    PEMEL  0.000e+00     elec
# 831  SIM24v2      BAT  H2C/H2S  0.000e+00     elec
# 832  SIM24v2      BAT     GRID  0.000e+00     elec
# 833  SIM24v2     GRID     LOAD  7.638e+04     elec
# 834  SIM24v2     GRID       HP  1.516e+04     elec
# 835  SIM24v2     GRID        P  6.594e-03     elec
# 836  SIM24v2     GRID      BAT  0.000e+00     elec
# 837  SIM24v2     GRID    PEMEL  0.000e+00     elec
# 838  SIM24v2     GRID  H2C/H2S  0.000e+00     elec
# 839  SIM24v2     GRID     GRID  0.000e+00     elec
# 840  SIM25v2  ICE-CHP     LOAD  4.345e+04     elec
# 841  SIM25v2  ICE-CHP       HP  1.824e+04     elec
# 842  SIM25v2  ICE-CHP        P  1.850e-02     elec
# 843  SIM25v2  ICE-CHP      BAT  0.000e+00     elec
# 844  SIM25v2  ICE-CHP    PEMEL  1.763e+04     elec
# 845  SIM25v2  ICE-CHP  H2C/H2S  1.637e+03     elec
# 846  SIM25v2  ICE-CHP     GRID  5.517e+04     elec
# 847  SIM25v2       WT     LOAD  2.296e-01     elec
# 848  SIM25v2       WT       HP  7.968e-02     elec
# 849  SIM25v2       WT        P  6.428e-08     elec
# 850  SIM25v2       WT      BAT  0.000e+00     elec
# 851  SIM25v2       WT    PEMEL  5.898e-02     elec
# 852  SIM25v2       WT  H2C/H2S  5.477e-03     elec
# 853  SIM25v2       WT     GRID  4.535e-01     elec
# 854  SIM25v2       PV     LOAD  1.762e+05     elec
# 855  SIM25v2       PV       HP  2.759e+04     elec
# 856  SIM25v2       PV        P  1.753e-02     elec
# 857  SIM25v2       PV      BAT  0.000e+00     elec
# 858  SIM25v2       PV    PEMEL  7.264e+05     elec
# 859  SIM25v2       PV  H2C/H2S  6.745e+04     elec
# 860  SIM25v2       PV     GRID  3.756e+08     elec
# 861  SIM25v2      BAT     LOAD  0.000e+00     elec
# 862  SIM25v2      BAT       HP  0.000e+00     elec
# 863  SIM25v2      BAT        P  0.000e+00     elec
# 864  SIM25v2      BAT      BAT  0.000e+00     elec
# 865  SIM25v2      BAT    PEMEL  0.000e+00     elec
# 866  SIM25v2      BAT  H2C/H2S  0.000e+00     elec
# 867  SIM25v2      BAT     GRID  0.000e+00     elec
# 868  SIM25v2     GRID     LOAD  7.763e+04     elec
# 869  SIM25v2     GRID       HP  1.816e+04     elec
# 870  SIM25v2     GRID        P  7.346e-03     elec
# 871  SIM25v2     GRID      BAT  0.000e+00     elec
# 872  SIM25v2     GRID    PEMEL  0.000e+00     elec
# 873  SIM25v2     GRID  H2C/H2S  0.000e+00     elec
# 874  SIM25v2     GRID     GRID  0.000e+00     elec
# 875  SIM26v2  ICE-CHP     LOAD  4.210e+04     elec
# 876  SIM26v2  ICE-CHP       HP  1.694e+04     elec
# 877  SIM26v2  ICE-CHP        P  1.774e-02     elec
# 878  SIM26v2  ICE-CHP      BAT  0.000e+00     elec
# 879  SIM26v2  ICE-CHP    PEMEL  1.910e+04     elec
# 880  SIM26v2  ICE-CHP  H2C/H2S  1.774e+03     elec
# 881  SIM26v2  ICE-CHP     GRID  5.343e+04     elec
# 882  SIM26v2       WT     LOAD  2.286e-01     elec
# 883  SIM26v2       WT       HP  8.127e-02     elec
# 884  SIM26v2       WT        P  6.372e-08     elec
# 885  SIM26v2       WT      BAT  0.000e+00     elec
# 886  SIM26v2       WT    PEMEL  5.958e-02     elec
# 887  SIM26v2       WT  H2C/H2S  5.532e-03     elec
# 888  SIM26v2       WT     GRID  4.522e-01     elec
# 889  SIM26v2       PV     LOAD  1.762e+05     elec
# 890  SIM26v2       PV       HP  2.744e+04     elec
# 891  SIM26v2       PV        P  1.753e-02     elec
# 892  SIM26v2       PV      BAT  0.000e+00     elec
# 893  SIM26v2       PV    PEMEL  7.080e+05     elec
# 894  SIM26v2       PV  H2C/H2S  6.574e+04     elec
# 895  SIM26v2       PV     GRID  3.756e+08     elec
# 896  SIM26v2      BAT     LOAD  0.000e+00     elec
# 897  SIM26v2      BAT       HP  0.000e+00     elec
# 898  SIM26v2      BAT        P  0.000e+00     elec
# 899  SIM26v2      BAT      BAT  0.000e+00     elec
# 900  SIM26v2      BAT    PEMEL  0.000e+00     elec
# 901  SIM26v2      BAT  H2C/H2S  0.000e+00     elec
# 902  SIM26v2      BAT     GRID  0.000e+00     elec
# 903  SIM26v2     GRID     LOAD  7.898e+04     elec
# 904  SIM26v2     GRID       HP  2.102e+04     elec
# 905  SIM26v2     GRID        P  8.104e-03     elec
# 906  SIM26v2     GRID      BAT  0.000e+00     elec
# 907  SIM26v2     GRID    PEMEL  0.000e+00     elec
# 908  SIM26v2     GRID  H2C/H2S  0.000e+00     elec
# 909  SIM26v2     GRID     GRID  0.000e+00     elec
# 910  SIM27v2  ICE-CHP     LOAD  3.989e+04     elec
# 911  SIM27v2  ICE-CHP       HP  1.474e+04     elec
# 912  SIM27v2  ICE-CHP        P  1.630e-02     elec
# 913  SIM27v2  ICE-CHP      BAT  0.000e+00     elec
# 914  SIM27v2  ICE-CHP    PEMEL  2.086e+04     elec
# 915  SIM27v2  ICE-CHP  H2C/H2S  1.937e+03     elec
# 916  SIM27v2  ICE-CHP     GRID  5.639e+04     elec
# 917  SIM27v2       WT     LOAD  2.278e-01     elec
# 918  SIM27v2       WT       HP  8.435e-02     elec
# 919  SIM27v2       WT        P  6.322e-08     elec
# 920  SIM27v2       WT      BAT  0.000e+00     elec
# 921  SIM27v2       WT    PEMEL  6.367e-02     elec
# 922  SIM27v2       WT  H2C/H2S  5.912e-03     elec
# 923  SIM27v2       WT     GRID  4.455e-01     elec
# 924  SIM27v2       PV     LOAD  1.762e+05     elec
# 925  SIM27v2       PV       HP  2.444e+04     elec
# 926  SIM27v2       PV        P  1.753e-02     elec
# 927  SIM27v2       PV      BAT  0.000e+00     elec
# 928  SIM27v2       PV    PEMEL  6.890e+05     elec
# 929  SIM27v2       PV  H2C/H2S  6.398e+04     elec
# 930  SIM27v2       PV     GRID  3.756e+08     elec
# 931  SIM27v2      BAT     LOAD  0.000e+00     elec
# 932  SIM27v2      BAT       HP  0.000e+00     elec
# 933  SIM27v2      BAT        P  0.000e+00     elec
# 934  SIM27v2      BAT      BAT  0.000e+00     elec
# 935  SIM27v2      BAT    PEMEL  0.000e+00     elec
# 936  SIM27v2      BAT  H2C/H2S  0.000e+00     elec
# 937  SIM27v2      BAT     GRID  0.000e+00     elec
# 938  SIM27v2     GRID     LOAD  8.120e+04     elec
# 939  SIM27v2     GRID       HP  2.600e+04     elec
# ...
# 947  SIM28v2  ICE-CHP        P  3.497e-03     elec
# 948  SIM28v2  ICE-CHP      BAT  0.000e+00     elec
# 949  SIM28v2  ICE-CHP    PEMEL  4.861e+03     elec
# 950  SIM28v2  ICE-CHP  H2C/H2S  4.513e+02     elec
# 951  SIM28v2  ICE-CHP     GRID  5.508e+04     elec
# 952  SIM28v2       WT     LOAD  2.184e-01     elec
# 953  SIM28v2       WT       HP  1.528e-01     elec
# 954  SIM28v2       WT        P  6.193e-08     elec
# 955  SIM28v2       WT      BAT  0.000e+00     elec
# 956  SIM28v2       WT    PEMEL  1.270e-02     elec
# 957  SIM28v2       WT  H2C/H2S  1.179e-03     elec
# 958  SIM28v2       WT     GRID  4.421e-01     elec
# 959  SIM28v2       PV     LOAD  1.762e+05     elec
# 960  SIM28v2       PV       HP  2.442e+04     elec
# 961  SIM28v2       PV        P  1.753e-02     elec
# 962  SIM28v2       PV      BAT  0.000e+00     elec
# 963  SIM28v2       PV    PEMEL  5.392e+05     elec
# 964  SIM28v2       PV  H2C/H2S  5.007e+04     elec
# 965  SIM28v2       PV     GRID  3.758e+08     elec
# 966  SIM28v2      BAT     LOAD  0.000e+00     elec
# 967  SIM28v2      BAT       HP  0.000e+00     elec
# 968  SIM28v2      BAT        P  0.000e+00     elec
# 969  SIM28v2      BAT      BAT  0.000e+00     elec
# 970  SIM28v2      BAT    PEMEL  0.000e+00     elec
# 971  SIM28v2      BAT  H2C/H2S  0.000e+00     elec
# 972  SIM28v2      BAT     GRID  0.000e+00     elec
# 973  SIM28v2     GRID     LOAD  1.099e+05     elec
# 974  SIM28v2     GRID       HP  6.644e+04     elec
# 975  SIM28v2     GRID        P  2.236e-02     elec
# 976  SIM28v2     GRID      BAT  0.000e+00     elec
# 977  SIM28v2     GRID    PEMEL  0.000e+00     elec
# 978  SIM28v2     GRID  H2C/H2S  0.000e+00     elec
# 979  SIM28v2     GRID     GRID  0.000e+00     elec
# 0    SIM01v2    PEMEL  ICE-CHP  5.529e+03       h2
# 1    SIM01v2    PEMEL  H2C/H2S  1.071e+04       h2
# 2    SIM01v2  H2C/H2S  ICE-CHP  6.500e+03       h2
# 3    SIM01v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 4    SIM02v2    PEMEL  ICE-CHP  5.459e+03       h2
# 5    SIM02v2    PEMEL  H2C/H2S  8.389e+03       h2
# 6    SIM02v2  H2C/H2S  ICE-CHP  6.917e+03       h2
# 7    SIM02v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 8    SIM03v2    PEMEL  ICE-CHP  5.033e+03       h2
# 9    SIM03v2    PEMEL  H2C/H2S  6.767e+03       h2
# 10   SIM03v2  H2C/H2S  ICE-CHP  7.476e+03       h2
# 11   SIM03v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 12   SIM04v2    PEMEL  ICE-CHP  4.882e+03       h2
# 13   SIM04v2    PEMEL  H2C/H2S  6.766e+03       h2
# 14   SIM04v2  H2C/H2S  ICE-CHP  7.396e+03       h2
# 15   SIM04v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 16   SIM05v2    PEMEL  ICE-CHP  5.010e+03       h2
# 17   SIM05v2    PEMEL  H2C/H2S  6.375e+03       h2
# 18   SIM05v2  H2C/H2S  ICE-CHP  7.124e+03       h2
# 19   SIM05v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 20   SIM06v2    PEMEL  ICE-CHP  5.224e+03       h2
# 21   SIM06v2    PEMEL  H2C/H2S  5.833e+03       h2
# 22   SIM06v2  H2C/H2S  ICE-CHP  6.763e+03       h2
# 23   SIM06v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 24   SIM07v2    PEMEL  ICE-CHP  4.048e+03       h2
# 25   SIM07v2    PEMEL  H2C/H2S  4.388e+03       h2
# 26   SIM07v2  H2C/H2S  ICE-CHP  3.510e+03       h2
# 27   SIM07v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 28   SIM08v2    PEMEL  ICE-CHP  4.996e+02       h2
# 29   SIM08v2    PEMEL  H2C/H2S  2.873e+03       h2
# 30   SIM08v2  H2C/H2S  ICE-CHP  2.511e+03       h2
# 31   SIM08v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 32   SIM09v2    PEMEL  ICE-CHP  8.538e+02       h2
# 33   SIM09v2    PEMEL  H2C/H2S  2.613e+03       h2
# 34   SIM09v2  H2C/H2S  ICE-CHP  2.534e+03       h2
# 35   SIM09v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 36   SIM10v2    PEMEL  ICE-CHP  1.311e+03       h2
# 37   SIM10v2    PEMEL  H2C/H2S  2.317e+03       h2
# 38   SIM10v2  H2C/H2S  ICE-CHP  2.211e+03       h2
# 39   SIM10v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 40   SIM11v2    PEMEL  ICE-CHP  1.386e+03       h2
# 41   SIM11v2    PEMEL  H2C/H2S  2.048e+03       h2
# 42   SIM11v2  H2C/H2S  ICE-CHP  2.010e+03       h2
# 43   SIM11v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 44   SIM12v2    PEMEL  ICE-CHP  1.415e+03       h2
# 45   SIM12v2    PEMEL  H2C/H2S  1.784e+03       h2
# 46   SIM12v2  H2C/H2S  ICE-CHP  1.759e+03       h2
# 47   SIM12v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 48   SIM13v2    PEMEL  ICE-CHP  1.519e+03       h2
# 49   SIM13v2    PEMEL  H2C/H2S  1.364e+03       h2
# 50   SIM13v2  H2C/H2S  ICE-CHP  1.351e+03       h2
# 51   SIM13v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 52   SIM14v2    PEMEL  ICE-CHP  1.359e+03       h2
# 53   SIM14v2    PEMEL  H2C/H2S  7.148e+02       h2
# 54   SIM14v2  H2C/H2S  ICE-CHP  7.064e+02       h2
# 55   SIM14v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 56   SIM15v2    PEMEL  ICE-CHP  4.417e+03       h2
# 57   SIM15v2    PEMEL  H2C/H2S  1.129e+04       h2
# 58   SIM15v2  H2C/H2S  ICE-CHP  7.573e+03       h2
# 59   SIM15v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 60   SIM16v2    PEMEL  ICE-CHP  4.231e+03       h2
# 61   SIM16v2    PEMEL  H2C/H2S  8.814e+03       h2
# 62   SIM16v2  H2C/H2S  ICE-CHP  7.812e+03       h2
# 63   SIM16v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 64   SIM17v2    PEMEL  ICE-CHP  3.839e+03       h2
# 65   SIM17v2    PEMEL  H2C/H2S  7.146e+03       h2
# 66   SIM17v2  H2C/H2S  ICE-CHP  8.083e+03       h2
# 67   SIM17v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 68   SIM18v2    PEMEL  ICE-CHP  3.756e+03       h2
# 69   SIM18v2    PEMEL  H2C/H2S  7.117e+03       h2
# 70   SIM18v2  H2C/H2S  ICE-CHP  7.924e+03       h2
# 71   SIM18v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 72   SIM19v2    PEMEL  ICE-CHP  3.960e+03       h2
# 73   SIM19v2    PEMEL  H2C/H2S  6.677e+03       h2
# 74   SIM19v2  H2C/H2S  ICE-CHP  7.498e+03       h2
# 75   SIM19v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 76   SIM20v2    PEMEL  ICE-CHP  4.463e+03       h2
# 77   SIM20v2    PEMEL  H2C/H2S  5.907e+03       h2
# 78   SIM20v2  H2C/H2S  ICE-CHP  7.042e+03       h2
# 79   SIM20v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 80   SIM21v2    PEMEL  ICE-CHP  3.433e+03       h2
# 81   SIM21v2    PEMEL  H2C/H2S  4.401e+03       h2
# 82   SIM21v2  H2C/H2S  ICE-CHP  3.130e+03       h2
# 83   SIM21v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 84   SIM22v2    PEMEL  ICE-CHP  4.371e+03       h2
# 85   SIM22v2    PEMEL  H2C/H2S  1.132e+04       h2
# 86   SIM22v2  H2C/H2S  ICE-CHP  7.620e+03       h2
# 87   SIM22v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 88   SIM23v2    PEMEL  ICE-CHP  4.198e+03       h2
# 89   SIM23v2    PEMEL  H2C/H2S  8.829e+03       h2
# 90   SIM23v2  H2C/H2S  ICE-CHP  7.834e+03       h2
# 91   SIM23v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 92   SIM24v2    PEMEL  ICE-CHP  3.772e+03       h2
# 93   SIM24v2    PEMEL  H2C/H2S  7.206e+03       h2
# 94   SIM24v2  H2C/H2S  ICE-CHP  8.174e+03       h2
# 95   SIM24v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 96   SIM25v2    PEMEL  ICE-CHP  3.771e+03       h2
# 97   SIM25v2    PEMEL  H2C/H2S  7.082e+03       h2
# 98   SIM25v2  H2C/H2S  ICE-CHP  7.926e+03       h2
# 99   SIM25v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 100  SIM26v2    PEMEL  ICE-CHP  3.907e+03       h2
# 101  SIM26v2    PEMEL  H2C/H2S  6.699e+03       h2
# 102  SIM26v2  H2C/H2S  ICE-CHP  7.554e+03       h2
# 103  SIM26v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 104  SIM27v2    PEMEL  ICE-CHP  4.440e+03       h2
# 105  SIM27v2    PEMEL  H2C/H2S  5.915e+03       h2
# 106  SIM27v2  H2C/H2S  ICE-CHP  7.059e+03       h2
# 107  SIM27v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 108  SIM28v2    PEMEL  ICE-CHP  3.418e+03       h2
# 109  SIM28v2    PEMEL  H2C/H2S  4.518e+03       h2
# 110  SIM28v2  H2C/H2S  ICE-CHP  2.995e+03       h2
# 111  SIM28v2  H2C/H2S  H2C/H2S  0.000e+00       h2
# 0    SIM01v2  ICE-CHP     LOAD  7.294e+05     heat
# 1    SIM01v2  ICE-CHP      TES  3.929e-14     heat
# 2    SIM01v2       HP     LOAD  6.806e+05     heat
# 3    SIM01v2       HP      TES  0.000e+00     heat
# 4    SIM01v2      TES     LOAD  2.619e-14     heat
# 5    SIM01v2      TES      TES  0.000e+00     heat
# 6    SIM02v2  ICE-CHP     LOAD  7.503e+05     heat
# 7    SIM02v2  ICE-CHP      TES  3.929e-14     heat
# 8    SIM02v2       HP     LOAD  6.597e+05     heat
# 9    SIM02v2       HP      TES  0.000e+00     heat
# 10   SIM02v2      TES     LOAD  2.619e-14     heat
# 11   SIM02v2      TES      TES  0.000e+00     heat
# 12   SIM03v2  ICE-CHP     LOAD  7.583e+05     heat
# 13   SIM03v2  ICE-CHP      TES  3.929e-14     heat
# 14   SIM03v2       HP     LOAD  6.517e+05     heat
# 15   SIM03v2       HP      TES  0.000e+00     heat
# 16   SIM03v2      TES     LOAD  2.619e-14     heat
# 17   SIM03v2      TES      TES  0.000e+00     heat
# 18   SIM04v2  ICE-CHP     LOAD  7.444e+05     heat
# 19   SIM04v2  ICE-CHP      TES  3.929e-14     heat
# 20   SIM04v2       HP     LOAD  6.656e+05     heat
# 21   SIM04v2       HP      TES  0.000e+00     heat
# 22   SIM04v2      TES     LOAD  2.619e-14     heat
# 23   SIM04v2      TES      TES  0.000e+00     heat
# 24   SIM05v2  ICE-CHP     LOAD  7.357e+05     heat
# 25   SIM05v2  ICE-CHP      TES  3.929e-14     heat
# 26   SIM05v2       HP     LOAD  6.743e+05     heat
# 27   SIM05v2       HP      TES  0.000e+00     heat
# 28   SIM05v2      TES     LOAD  2.619e-14     heat
# 29   SIM05v2      TES      TES  0.000e+00     heat
# 30   SIM06v2  ICE-CHP     LOAD  7.268e+05     heat
# 31   SIM06v2  ICE-CHP      TES  3.929e-14     heat
# 32   SIM06v2       HP     LOAD  6.832e+05     heat
# 33   SIM06v2       HP      TES  0.000e+00     heat
# 34   SIM06v2      TES     LOAD  2.619e-14     heat
# 35   SIM06v2      TES      TES  0.000e+00     heat
# 36   SIM07v2  ICE-CHP     LOAD  4.586e+05     heat
# 37   SIM07v2  ICE-CHP      TES  2.619e-14     heat
# 38   SIM07v2       HP     LOAD  9.514e+05     heat
# 39   SIM07v2       HP      TES  0.000e+00     heat
# 40   SIM07v2      TES     LOAD  2.619e-14     heat
# 41   SIM07v2      TES      TES  0.000e+00     heat
# 42   SIM08v2  ICE-CHP     LOAD  1.829e+05     heat
# 43   SIM08v2  ICE-CHP      TES  1.310e-14     heat
# 44   SIM08v2       HP     LOAD  1.227e+06     heat
# 45   SIM08v2       HP      TES  0.000e+00     heat
# 46   SIM08v2      TES     LOAD  1.310e-14     heat
# 47   SIM08v2      TES      TES  0.000e+00     heat
# 48   SIM09v2  ICE-CHP     LOAD  2.061e+05     heat
# 49   SIM09v2  ICE-CHP      TES  2.619e-14     heat
# 50   SIM09v2       HP     LOAD  1.204e+06     heat
# 51   SIM09v2       HP      TES  0.000e+00     heat
# 52   SIM09v2      TES     LOAD  2.619e-14     heat
# 53   SIM09v2      TES      TES  0.000e+00     heat
# 54   SIM10v2  ICE-CHP     LOAD  2.144e+05     heat
# 55   SIM10v2  ICE-CHP      TES  2.619e-14     heat
# 56   SIM10v2       HP     LOAD  1.196e+06     heat
# 57   SIM10v2       HP      TES  0.000e+00     heat
# 58   SIM10v2      TES     LOAD  2.619e-14     heat
# 59   SIM10v2      TES      TES  0.000e+00     heat
# 60   SIM11v2  ICE-CHP     LOAD  2.066e+05     heat
# 61   SIM11v2  ICE-CHP      TES  1.310e-14     heat
# 62   SIM11v2       HP     LOAD  1.203e+06     heat
# 63   SIM11v2       HP      TES  0.000e+00     heat
# 64   SIM11v2      TES     LOAD  1.310e-14     heat
# 65   SIM11v2      TES      TES  0.000e+00     heat
# 66   SIM12v2  ICE-CHP     LOAD  1.930e+05     heat
# 67   SIM12v2  ICE-CHP      TES  1.310e-14     heat
# 68   SIM12v2       HP     LOAD  1.217e+06     heat
# 69   SIM12v2       HP      TES  0.000e+00     heat
# 70   SIM12v2      TES     LOAD  1.310e-14     heat
# 71   SIM12v2      TES      TES  0.000e+00     heat
# 72   SIM13v2  ICE-CHP     LOAD  1.746e+05     heat
# 73   SIM13v2  ICE-CHP      TES  1.310e-14     heat
# 74   SIM13v2       HP     LOAD  1.235e+06     heat
# 75   SIM13v2       HP      TES  0.000e+00     heat
# 76   SIM13v2      TES     LOAD  2.619e-14     heat
# 77   SIM13v2      TES      TES  0.000e+00     heat
# 78   SIM14v2  ICE-CHP     LOAD  1.255e+05     heat
# 79   SIM14v2  ICE-CHP      TES  0.000e+00     heat
# 80   SIM14v2       HP     LOAD  1.285e+06     heat
# 81   SIM14v2       HP      TES  0.000e+00     heat
# 82   SIM14v2      TES     LOAD  2.619e-14     heat
# 83   SIM14v2      TES      TES  0.000e+00     heat
# 84   SIM15v2  ICE-CHP     LOAD  7.271e+05     heat
# 85   SIM15v2  ICE-CHP      TES  3.929e-14     heat
# 86   SIM15v2       HP     LOAD  6.830e+05     heat
# 87   SIM15v2       HP      TES  0.000e+00     heat
# 88   SIM15v2      TES     LOAD  2.619e-14     heat
# 89   SIM15v2      TES      TES  0.000e+00     heat
# 90   SIM16v2  ICE-CHP     LOAD  7.302e+05     heat
# 91   SIM16v2  ICE-CHP      TES  3.929e-14     heat
# 92   SIM16v2       HP     LOAD  6.798e+05     heat
# 93   SIM16v2       HP      TES  0.000e+00     heat
# 94   SIM16v2      TES     LOAD  2.619e-14     heat
# 95   SIM16v2      TES      TES  0.000e+00     heat
# 96   SIM17v2  ICE-CHP     LOAD  7.230e+05     heat
# 97   SIM17v2  ICE-CHP      TES  3.929e-14     heat
# 98   SIM17v2       HP     LOAD  6.870e+05     heat
# 99   SIM17v2       HP      TES  0.000e+00     heat
# 100  SIM17v2      TES     LOAD  2.619e-14     heat
# 101  SIM17v2      TES      TES  0.000e+00     heat
# 102  SIM18v2  ICE-CHP     LOAD  7.084e+05     heat
# 103  SIM18v2  ICE-CHP      TES  3.929e-14     heat
# 104  SIM18v2       HP     LOAD  7.016e+05     heat
# 105  SIM18v2       HP      TES  0.000e+00     heat
# 106  SIM18v2      TES     LOAD  2.619e-14     heat
# 107  SIM18v2      TES      TES  0.000e+00     heat
# 108  SIM19v2  ICE-CHP     LOAD  6.951e+05     heat
# 109  SIM19v2  ICE-CHP      TES  3.929e-14     heat
# 110  SIM19v2       HP     LOAD  7.150e+05     heat
# 111  SIM19v2       HP      TES  0.000e+00     heat
# 112  SIM19v2      TES     LOAD  2.619e-14     heat
# 113  SIM19v2      TES      TES  0.000e+00     heat
# 114  SIM20v2  ICE-CHP     LOAD  6.978e+05     heat
# 115  SIM20v2  ICE-CHP      TES  3.929e-14     heat
# 116  SIM20v2       HP     LOAD  7.122e+05     heat
# 117  SIM20v2       HP      TES  0.000e+00     heat
# 118  SIM20v2      TES     LOAD  2.619e-14     heat
# 119  SIM20v2      TES      TES  0.000e+00     heat
# 120  SIM21v2  ICE-CHP     LOAD  3.984e+05     heat
# 121  SIM21v2  ICE-CHP      TES  2.619e-14     heat
# 122  SIM21v2       HP     LOAD  1.012e+06     heat
# 123  SIM21v2       HP      TES  0.000e+00     heat
# 124  SIM21v2      TES     LOAD  2.619e-14     heat
# 125  SIM21v2      TES      TES  0.000e+00     heat
# 126  SIM22v2  ICE-CHP     LOAD  7.271e+05     heat
# 127  SIM22v2  ICE-CHP      TES  3.929e-14     heat
# 128  SIM22v2       HP     LOAD  6.830e+05     heat
# 129  SIM22v2       HP      TES  0.000e+00     heat
# 130  SIM22v2      TES     LOAD  2.619e-14     heat
# 131  SIM22v2      TES      TES  0.000e+00     heat
# 132  SIM23v2  ICE-CHP     LOAD  7.296e+05     heat
# 133  SIM23v2  ICE-CHP      TES  3.929e-14     heat
# 134  SIM23v2       HP     LOAD  6.804e+05     heat
# 135  SIM23v2       HP      TES  0.000e+00     heat
# 136  SIM23v2      TES     LOAD  2.619e-14     heat
# 137  SIM23v2      TES      TES  0.000e+00     heat
# 138  SIM24v2  ICE-CHP     LOAD  7.244e+05     heat
# 139  SIM24v2  ICE-CHP      TES  3.929e-14     heat
# 140  SIM24v2       HP     LOAD  6.856e+05     heat
# 141  SIM24v2       HP      TES  0.000e+00     heat
# 142  SIM24v2      TES     LOAD  2.619e-14     heat
# 143  SIM24v2      TES      TES  0.000e+00     heat
# 144  SIM25v2  ICE-CHP     LOAD  7.094e+05     heat
# 145  SIM25v2  ICE-CHP      TES  3.929e-14     heat
# 146  SIM25v2       HP     LOAD  7.006e+05     heat
# 147  SIM25v2       HP      TES  0.000e+00     heat
# 148  SIM25v2      TES     LOAD  2.619e-14     heat
# 149  SIM25v2      TES      TES  0.000e+00     heat
# 150  SIM26v2  ICE-CHP     LOAD  6.952e+05     heat
# 151  SIM26v2  ICE-CHP      TES  3.929e-14     heat
# 152  SIM26v2       HP     LOAD  7.148e+05     heat
# 153  SIM26v2       HP      TES  0.000e+00     heat
# 154  SIM26v2      TES     LOAD  2.619e-14     heat
# 155  SIM26v2      TES      TES  0.000e+00     heat
# 156  SIM27v2  ICE-CHP     LOAD  6.974e+05     heat
# 157  SIM27v2  ICE-CHP      TES  3.929e-14     heat
# 158  SIM27v2       HP     LOAD  7.126e+05     heat
# 159  SIM27v2       HP      TES  0.000e+00     heat
# 160  SIM27v2      TES     LOAD  2.619e-14     heat
# 161  SIM27v2      TES      TES  0.000e+00     heat
# 162  SIM28v2  ICE-CHP     LOAD  3.893e+05     heat
# 163  SIM28v2  ICE-CHP      TES  2.619e-14     heat
# 164  SIM28v2       HP     LOAD  1.021e+06     heat
# 165  SIM28v2       HP      TES  0.000e+00     heat
# 166  SIM28v2      TES     LOAD  2.619e-14     heat
# 167  SIM28v2      TES      TES  0.000e+00     heat
